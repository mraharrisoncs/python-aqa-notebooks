# %% [markdown]
# # Lesson 1 - Simple selection
#
# Introduction to selection.
#
# **Learning objectives:**
# 1. Why do we need selection?
# 2. Boolean expressions.
# 3. Using if and if-else.
#
# ---

# %% [markdown]
# ### Why Selection?
#
# ## Sequences
#
# Programs that use only sequences of operations are not very useful. Remember this program?
#
# ```python
# colour = input("What is your favourite colour?")
# print("I like", colour, "too!")
# ```
#
# But what if the computer's favourite colour is blue, and the user enters "red"? In this case we might want the program to say "Good choice, but I like blue best".
#
# ## Selection
#
# Here's how we do that:
#
# ```python
# colour = input("What is your favourite colour?")
# if colour == "blue":
#   print("I like", colour, "too!")
# else:
#   print("Good choice, but I like blue best")
# ```
#
# Python gives us the keywords `if` and `else` to control the **flow** of the program. In the above example, if the user enters "blue", the program will output "I like blue too!", if they enter anything else it will say "Good choice..."
#
# ## Try it out
#
# Before we dive deeper into how this works, try it for yourself. Open the attached program and...
#
# 1. Predict what it does.
# 2. Change the program so that instead of giving advice about the rain, if the input is "sunny" the program says "Wear sunscreen".
# 3. Add another question, "Are you going to school? " and if the answer is "yes" then say "Remember your books", otherwise say "Have fun!".

# %%
# weather.py
weather = input("What is the weather today? ")
if weather == "raining":
    print("Take an umbrella")
else:
    print("Good to go!")

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %% [markdown]
# **Q1.** *(Reflection)*
# How did you get on? Did you remember to change the name of the variable from 'weather' for the 3rd task? We should always use meaningful variables.
#
# *Write your thoughts in the cell below.*

# %%
# Q1 — your reflection
reflection = """

"""

# %% [markdown]
# ---

# %% [markdown]
# ### Structure of IF-ELSE
#
# <br />
#
# Remember this program? Let's look at this code in more detail.
#
# ```python
# weather = input("What is the weather today? ")
# if weather == "raining":
#     print("Take an umbrella")
# else:
#     print("Good to go!")
# ```
#
# ### Explanation
#
# The second line tells Python we need to evaluate the **expression** `weather == "raining"` to decide which line to execute next
#
# > Tip: remember an **expression** is any valid sequence of **terms** and **operators** that can be **evaluated** to obtain a **result**. We met **arithmetic expressions** earlier in the course, which always evaluate to numbers. Here we have a **Boolean expression**, which evaluates to either **True** or **False.**
#
# * The expression, `weather == "raining"` will evaluate to `True` if the variable `weather` holds the string "raining".
#
# * If the expression is `True`, Python executes the next line.
#
# * If the expression is `False`, Python skips all the indented code, and because it finds an `else:` keyword it executes the code block after this. (`else:` is optional, as we will see later.)
#
# > *Exam tip:* An if-else statement is called a **binary** conditional statement, because there are **two** branches of code to choose from, and binary means ***two-ness*****.**
#
# ## '=' versus '=='
#
# In `if` statements, we always use two equals signs, not just one. This is because `==` means something different to `=` .
#
# In Unit 1 we learned about variables and how to give them values. You may recall **assignment** means giving a value to a variable, like this:
#
# ```python
# name = "Ada"       # this is an assignment statement, so a single equals sign is needed
# ```
#
# But now we are performing **selection**, which uses **Boolean expressions**, where we compare two values to see if they are equal. For this we need `==` which means **is equal to**.
#
# ```python
# if name == "Ada":  # this is a Boolean expression, so we need to use two equals signs
# ```
#
# ## Flowchart for if-else
#
# Here is a flowchart to illustrate what is going on:
#
# ![1.00](data:image/svg+xml;base64,...)
#
# The program chooses to execute **either** the left branch **or** the right branch, but not both. The value of the variable `weather` decides which branch executes. If the variable's value matches the string "raining", then the Boolean expression evaluates to **True** and the left branch is chosen, otherwise the right branch is chosen.
#
# Now check your understanding.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp1_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> Python uses which of these keywords to indicate selection?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_1" value="def"
                 onchange="_qchecku3l0_lp1_1(this.value)"> def
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_1" value="if"
                 onchange="_qchecku3l0_lp1_1(this.value)"> if
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_1" value="print()"
                 onchange="_qchecku3l0_lp1_1(this.value)"> print()
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_1" value="=="
                 onchange="_qchecku3l0_lp1_1(this.value)"> ==
        </label>
  <div id="qu3l0_lp1_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp1_1_correct = "if";
  var _qu3l0_lp1_1_explanations = {"def": "No, this defines a function or procedure.", "if": "Yes, the if statement indicates selection", "print()": "No, print() puts output on the screen", "==": "No, == is an operator used in some conditions, but not all of them, and it is not a keyword."};
  function _qchecku3l0_lp1_1(val) {
    var fb = document.getElementById("qu3l0_lp1_1_fb");
    var expl = _qu3l0_lp1_1_explanations[val] || "";
    if (val === _qu3l0_lp1_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp1_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> What would be the output of this code?\<br\>\<br\>
if 5 \> 5:\<br\>
&nbsp;&nbsp;&nbsp;&nbsp;print("yes")\<br\>
else:\<br\>
&nbsp;&nbsp;&nbsp;&nbsp;print("no")\<br\></p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_2" value="True"
                 onchange="_qchecku3l0_lp1_2(this.value)"> True
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_2" value="False"
                 onchange="_qchecku3l0_lp1_2(this.value)"> False
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_2" value="5"
                 onchange="_qchecku3l0_lp1_2(this.value)"> 5
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_2" value="Syntax Error"
                 onchange="_qchecku3l0_lp1_2(this.value)"> Syntax Error
        </label>
  <div id="qu3l0_lp1_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp1_2_correct = "False";
  var _qu3l0_lp1_2_explanations = {"True": "No, 5 is not greater than 5, so the else branch will be executed", "False": "Yes, 5 \\> 5 evaluates to False so the else branch is executed", "5": "No, the only possible answers are \"yes\" and \"no\"", "Syntax Error": "No, the code is syntactically correct"};
  function _qchecku3l0_lp1_2(val) {
    var fb = document.getElementById("qu3l0_lp1_2_fb");
    var expl = _qu3l0_lp1_2_explanations[val] || "";
    if (val === _qu3l0_lp1_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp1_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> What flowchart shape is used to represent selection?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_3" value="Square or rectangle"
                 onchange="_qchecku3l0_lp1_3(this.value)"> Square or rectangle
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_3" value="Oval or rounded rectangle"
                 onchange="_qchecku3l0_lp1_3(this.value)"> Oval or rounded rectangle
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_3" value="Rhombus or diamond"
                 onchange="_qchecku3l0_lp1_3(this.value)"> Rhombus or diamond
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp1_3" value="Parallelogram"
                 onchange="_qchecku3l0_lp1_3(this.value)"> Parallelogram
        </label>
  <div id="qu3l0_lp1_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp1_3_correct = "Rhombus or diamond";
  var _qu3l0_lp1_3_explanations = {"Square or rectangle": "", "Oval or rounded rectangle": "", "Rhombus or diamond": "", "Parallelogram": ""};
  function _qchecku3l0_lp1_3(val) {
    var fb = document.getElementById("qu3l0_lp1_3_fb");
    var expl = _qu3l0_lp1_3_explanations[val] || "";
    if (val === _qu3l0_lp1_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Boolean Expressions - comparing things
#
# ### Boolean Expressions in IF statements
#
# Remember, a Boolean expression is an expression that evaluates to either `True` or `False`. We use the result to control the flow of a program by using selection statements like `if` and `else`. We were looking at this example program:
#
# ```python
# weather = input("What is the weather today? ")
# if weather == "raining":
#   print("Take an umbrella")
# else:
#   print("Good to go!")
# ```
#
# The Boolean expression here is `weather == "raining"`, which always evaluates to either True or False, nothing else. We can use **any** Boolean expression as the condition on an `if` statement. Anything that evaluates to `True` or `False` can control an `if` statement.
#
# #### Comparison Operators
#
# In the above example, `==` is a **comparison operator** because it compares two values, in this case the contents of the variable `weather` and the string literal "raining". Putting two **operands** like this either side of a comparison operator makes a valid **Boolean expression,** which evaluates to a **Boolean value**: either `True` or `False`.
#
# Here are the common comparison operators in Python:
#
# * `==`: Equal to
#
# * `!=`: Not equal to
#
# * `>`: Greater than
#
# * `>=`: Greater than or equal to
#
# * `<`: Less than
#
# * `<=`: Less than or equal to
#
# #### Writing a Boolean Expression
#
# A Boolean expression involves a comparison **operator** and two **operands,** one either side. Read through these examples and consider why we get the output shown:
#
# ```python
# >>> x = 10
# >>> y = 20
#
# >>> print(x == y)
# False
#
# >>> print(x != y)
# True
#
# >>> print(x > y)
# False
#
# >>> print(x <= y)
# True
# ```
#
# Check your understanding now.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp2_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> What are the operands in this Boolean expression?
age \>= 18</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_1" value="age, 18"
                 onchange="_qchecku3l0_lp2_1(this.value)"> age, 18
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_1" value="\>, ="
                 onchange="_qchecku3l0_lp2_1(this.value)"> \>, =
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_1" value="age, \>"
                 onchange="_qchecku3l0_lp2_1(this.value)"> age, \>
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_1" value="=, 18"
                 onchange="_qchecku3l0_lp2_1(this.value)"> =, 18
        </label>
  <div id="qu3l0_lp2_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp2_1_correct = "age, 18";
  var _qu3l0_lp2_1_explanations = {"age, 18": "Yes, the operands are the terms either side of the operator", "\\>, =": "No, these are parts of the operator", "age, \\>": "No, \\> is part of the operator", "=, 18": "No, = is part of the operator"};
  function _qchecku3l0_lp2_1(val) {
    var fb = document.getElementById("qu3l0_lp2_1_fb");
    var expl = _qu3l0_lp2_1_explanations[val] || "";
    if (val === _qu3l0_lp2_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp2_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> Which comparison operator would be needed in an if statement to do the following?
Check if a baby's weight is at least 3.5kg?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_2" value="\>="
                 onchange="_qchecku3l0_lp2_2(this.value)"> \>=
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_2" value="\<="
                 onchange="_qchecku3l0_lp2_2(this.value)"> \<=
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_2" value="=="
                 onchange="_qchecku3l0_lp2_2(this.value)"> ==
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_2" value="\>"
                 onchange="_qchecku3l0_lp2_2(this.value)"> \>
        </label>
  <div id="qu3l0_lp2_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp2_2_correct = "\\>=";
  var _qu3l0_lp2_2_explanations = {"\\>=": "Yes, \"at least\" is a synonym for \"greater than or equal to\"", "\\<=": "No, this is \"less than or equal to\"?", "==": "No, this is equals, or \"exactly equal to\"", "\\>": "No, this is greater than, and we need a weight of exactly 3.5 to result in True."};
  function _qchecku3l0_lp2_2(val) {
    var fb = document.getElementById("qu3l0_lp2_2_fb");
    var expl = _qu3l0_lp2_2_explanations[val] || "";
    if (val === _qu3l0_lp2_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp2_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> What does this Boolean expression evaluate to?
"chalk" != "cheese"</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_3" value="True"
                 onchange="_qchecku3l0_lp2_3(this.value)"> True
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_3" value="False"
                 onchange="_qchecku3l0_lp2_3(this.value)"> False
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_3" value="chalk"
                 onchange="_qchecku3l0_lp2_3(this.value)"> chalk
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp2_3" value="cheese"
                 onchange="_qchecku3l0_lp2_3(this.value)"> cheese
        </label>
  <div id="qu3l0_lp2_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp2_3_correct = "True";
  var _qu3l0_lp2_3_explanations = {"True": "Correct, \"chalk\" is not the same as \"cheese\"!", "False": "No, the != operator means \"not equal to\".", "chalk": "No, a Boolean expression always evaluates to either True or False", "cheese": "No, a Boolean expression always evaluates to either True or False"};
  function _qchecku3l0_lp2_3(val) {
    var fb = document.getElementById("qu3l0_lp2_3_fb");
    var expl = _qu3l0_lp2_3_explanations[val] || "";
    if (val === _qu3l0_lp2_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Programming if-else
#
# A **Boolean expression** is used in an `if-else` statement to decide which block of code should be executed.
#
# ## Can you vote?
#
# Here's another example that uses `>=` (greater than or equal to), and this time we have wrapped the code in a **function** definition with `def`:
#
# ```python
# def canVote(age):
#     if age >= 18:
#         print("You are eligible to vote")
#     else:
#         print("You are not eligible to vote")
#
# # main program
# myAge = int(input("Age? "))
# print(canVote(myAge))
# ```
#
# ### Explanation
#
# In this example, the Boolean expression `age >= 18` is evaluated. If `True`, the program prints "You are eligible to vote". Otherwise, it prints "You are not eligible to vote".
#
# ## Speed warning function
#
#
#
# Here is another example, a **function** that takes speed as a parameter, and returns a string. I've also used a variable as if it is a **constant** at the top of the code, remembering to use all capitals. This 'constant' allows us to easily change the value later, for example if the speed limit becomes 20.
#
# ```python
# SPEED_LIMIT = 30
#
# def speedCheck(currentSpeed):
#     if currentSpeed <= SPEED_LIMIT:
#         return "Safe driving, keep going."
#     else:
#         return "Too fast, slow down!"
#
# # main program
# speed = int(input("Current speed? "))
# print(speedCheck(speed))
# ```
#
# ### Explanation
#
# This time, the Boolean expression has two **variables** as the operands, and `less than or equal to` as the comparison operator. The expression `currentSpeed <= SPEED_LIMIT` is evaluated. If `True`, the **function** will return the string "Safe driving, keep going." Otherwise, it returns "Too fast, slow down!"
#
# Back in the main program, the return value is printed, because we wrote `print(speedCheck(speed)).`
#
# ## Pseudocode notes
#
# Programming languages use combinations of basic symbols such as `!=` and `<=` because these symbols are available in ASCII and can be entered directly on computer keyboards. In AQA exams, however, we use the standard mathematical symbols for comparison operators: `=`, `≥` and `≤`. Also we use the keywords `IF`, `THEN`, `ELSE` and `ENDIF`, and don't forget we use `OUTPUT` for `print()`, so the 'weather' example looks like this...
#
# ```python
# IF weather = "raining" THEN
#     OUTPUT "Take an umbrella"
# ELSE
#     OUTPUT "Good to go!"
# ENDIF
# ```
#
# ...the voting example like this...
#
# ```python
# IF age ≥ 18 THEN
#     OUTPUT "You are eligible to vote"
# ELSE
#     OUTPUT "You are not eligible to vote"
# ENDIF
# ```
#
# ...and the speed check example like this:
#
# ```python
# IF currentSpeed ≤ SPEED_LIMIT THEN
#     RETURN "Safe driving, keep going."
# ELSE
#     RETURN "Too fast, slow down!"
# ENDIF
# ```
#
# Check your understanding now.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp3_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> What is the output of this code?
pension_age = 67 \<br\>
age = 67\<br\>
if age \>= pension_age:\<br\>
&nbsp;&nbsp;&nbsp;&nbsp;print("State pension due")\<br\>
else:\<br\>
&nbsp;&nbsp;&nbsp;&nbsp;print("Not yet!")\<br\></p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp3_1" value="State pension due"
                 onchange="_qchecku3l0_lp3_1(this.value)"> State pension due
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp3_1" value="Not yet"
                 onchange="_qchecku3l0_lp3_1(this.value)"> Not yet
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp3_1" value="67"
                 onchange="_qchecku3l0_lp3_1(this.value)"> 67
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp3_1" value="Syntax Error"
                 onchange="_qchecku3l0_lp3_1(this.value)"> Syntax Error
        </label>
  <div id="qu3l0_lp3_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp3_1_correct = "State pension due";
  var _qu3l0_lp3_1_explanations = {"State pension due": "Yes, 67 \\>= 67 evaluates to True", "Not yet": "No, 67 \\>= 67 evaluates to True", "67": "No, the output is one of the strings", "Syntax Error": "No, the code is syntactically correct"};
  function _qchecku3l0_lp3_1(val) {
    var fb = document.getElementById("qu3l0_lp3_1_fb");
    var expl = _qu3l0_lp3_1_explanations[val] || "";
    if (val === _qu3l0_lp3_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp3_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> The pseudocode statement IF temperature ≥ 21 THEN would be written in Python as which of these?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp3_2" value="if temperature \>= 21:"
                 onchange="_qchecku3l0_lp3_2(this.value)"> if temperature \>= 21:
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp3_2" value="if temperature \<= 21:"
                 onchange="_qchecku3l0_lp3_2(this.value)"> if temperature \<= 21:
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp3_2" value="if temperature \>= 21"
                 onchange="_qchecku3l0_lp3_2(this.value)"> if temperature \>= 21
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp3_2" value="if temperature != 21:"
                 onchange="_qchecku3l0_lp3_2(this.value)"> if temperature != 21:
        </label>
  <div id="qu3l0_lp3_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp3_2_correct = "if temperature \\>= 21:";
  var _qu3l0_lp3_2_explanations = {"if temperature \\>= 21:": "Yes, the ≥ symbol must be written as \\>=", "if temperature \\<= 21:": "No, the ≥ symbol is not \\<=", "if temperature \\>= 21": "You need a punctuation mark in Python to indicate that an indented code block follows", "if temperature != 21:": "No, the ≥ symbol means greater than or equal to, != means not equal to"};
  function _qchecku3l0_lp3_2(val) {
    var fb = document.getElementById("qu3l0_lp3_2_fb");
    var expl = _qu3l0_lp3_2_explanations[val] || "";
    if (val === _qu3l0_lp3_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp3_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> What combination of two symbols is used in Python to mean "less than or equal to"? Type just two characters.</p>
  <input id="qu3l0_lp3_3_in" type="text" placeholder="Type your answer..."
         style="padding:4px 8px;width:50%;border:1px solid #ccc;border-radius:4px">
  <button onclick="_qchecku3l0_lp3_3()"
          style="margin-left:8px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu3l0_lp3_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp3_3_correct = "\\<=";
  var _qu3l0_lp3_3_explanation = "Yes, '\\<' is the less-than sign, and '=' is the equals sign, so '\\<=' means 'less than or equal to'.";
  function _qchecku3l0_lp3_3() {
    var answer = document.getElementById("qu3l0_lp3_3_in").value.trim().toLowerCase();
    var fb = document.getElementById("qu3l0_lp3_3_fb");
    if (answer === "") {
      fb.innerHTML = "<span style='color:grey'>&#128161; Answer: <b>" + _qu3l0_lp3_3_correct + "</b> &mdash; " + _qu3l0_lp3_3_explanation + "</span>";
    } else if (answer === _qu3l0_lp3_3_correct.toLowerCase()) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + _qu3l0_lp3_3_explanation + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite &mdash; try again, or clear your answer and click Check to reveal.</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Python practical - if-else
#
# ## Python if-else exercises
#
# ### 1. Positive or Negative?
#
# Starting with the code in **q1.py**, write a function that uses an if-else statement to determine if a number is positive or negative. Return "positive" if the number is greater than zero, otherwise return "negative".
#
# ### 2: Even or Odd?
#
# Complete the function in **q2.py**  to check if a number is even or odd. Return "even" if the number is divisible by 2, otherwise return "odd". *Hint: remember the modulus operator % from Unit 2, which returns the remainder. If the remainder after dividing by 2 is zero, the number is even.*
#
# ### 3: Compare Two Numbers
#
# Complete the code in **q3.py** to compare two numbers and return "First is greater" if the first number is greater than the second, otherwise return "First is not greater".

# %%
# q1.py
def positiveChecker(number):
    pass
    # TODO: delete 'pass" and write your code here

# main program
num = float(input("Enter a number: "))
print(positiveChecker(num))

# %%
# q2.py
def evenChecker(number):
    pass
    # TODO: delete 'pass" and write your code here

# main program
num = int(input("Enter a number: "))
print(evenChecker(num))

# %%
# q3.py
def compare(n1, n2):
    pass
    # TODO: delete 'pass" and write your code here

# main program
firstNumber = float(input("Enter the first number: "))
secondNumber = float(input("Enter the second number: "))
# TODO: write a statement here to call the function
# and print the return value

# %% [markdown]
# ---

# %% [markdown]
# ### IF without ELSE
#
# # IF without ELSE
#
# We have talked about `if-else` so far, because we usually write selection with two branches. The Boolean expression decides which branch is executed, like this:
#
# ```python
# weather = input("What is the weather today? ")
# if weather == "raining":
#     print("Take an umbrella")
# else:
#     print("Good to go!")
# ```
#
# Which looks like this in a flowchart:
#
# ![1.00](data:image/svg+xml;base64,...)
#
# But sometimes we do not need the second branch. Here is an example:
#
# Write a program to ask if someone wants milk in their tea. Output instructions to make the drink:
#
# ```python
# print("make the tea")
# milk = input("Do you want milk?")
# if milk == "yes":
#     print("add milk")
# print("stir and drink the tea")
# ```
#
# Notice that there is no `else` statement, because there is no alternative path the program needs to take.
#
# Here is another example.  Train tickets are 30% cheaper with a student railcard (or 70% of the standard price!)
#
# ```python
# fare = 10.00
# railcard = input("Do you have a railcard")
# if railcard == "yes":
#     fare = fare * 0.7
# print("fare =", fare)
# ```
#
# Again there is no need for an `else` statement, because the fare remains at £10 without a railcard, there is no need to do anything to it.
#
# > *Exam tip:* this is called a **unary** conditional, because it only has **one** branch, and unary means ***one-ness***.
#
# The flowchart for an if statement without else looks like this:
#
# ![1.00](data:image/svg+xml;base64,...)
#
# Check your understanding.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp5_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> True or false: IF statement must always have an ELSE branch?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp5_1" value="False"
                 onchange="_qchecku3l0_lp5_1(this.value)"> False
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp5_1" value="True"
                 onchange="_qchecku3l0_lp5_1(this.value)"> True
        </label>
  <div id="qu3l0_lp5_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp5_1_correct = "False";
  var _qu3l0_lp5_1_explanations = {"False": "Correct, ELSE is optional", "True": "No, you do not need to code ELSE in an IF statement."};
  function _qchecku3l0_lp5_1(val) {
    var fb = document.getElementById("qu3l0_lp5_1_fb");
    var expl = _qu3l0_lp5_1_explanations[val] || "";
    if (val === _qu3l0_lp5_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l0_lp5_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> If you run the railcard program above, what would be the output if the user does NOT have a railcard?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp5_2" value="fare = 10.0"
                 onchange="_qchecku3l0_lp5_2(this.value)"> fare = 10.0
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp5_2" value="fare = 0.7"
                 onchange="_qchecku3l0_lp5_2(this.value)"> fare = 0.7
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp5_2" value="fare = 0.3"
                 onchange="_qchecku3l0_lp5_2(this.value)"> fare = 0.3
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu3l0_lp5_2" value="10.0"
                 onchange="_qchecku3l0_lp5_2(this.value)"> 10.0
        </label>
  <div id="qu3l0_lp5_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l0_lp5_2_correct = "fare = 10.0";
  var _qu3l0_lp5_2_explanations = {"fare = 10.0": "Correct, the fare is unchanged", "fare = 0.7": "Wrong, the condition is FALSE so the indented line does not run", "fare = 0.3": "Wrong, the condition is FALSE so the fare is not changed", "10.0": "You forgot the output \"fare =\""};
  function _qchecku3l0_lp5_2(val) {
    var fb = document.getElementById("qu3l0_lp5_2_fb");
    var expl = _qu3l0_lp5_2_explanations[val] || "";
    if (val === _qu3l0_lp5_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---
