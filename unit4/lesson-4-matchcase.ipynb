# %% [markdown]
# # Lesson 4 - match/case
#
# Selection using match/case in Python
#
# **Learning objectives:**
# match/case
#
# ---

# %% [markdown]
# ### Downsides of if-elif-else
#
# As we saw in the last lesson. when coding **selection** with multiple conditions, you might use an `if-elif-else` structure. But this can become cumbersome and error-prone when dealing with many branches. Let's look at an example:
#
# ### Issues with `if-elif-else` for long conditionals
#
# In an `if-elif-else` chain, you often repeat the same variable or expression multiple times. This repetition can make the code harder to read and maintain. Remember our food ordering menu?
#
# ```python
# if choice == 1:
#     starterMenu()
# elif choice == 2:
#     maincourseMenu()
# elif choice == 3:
#     dessertMenu()
# else:
#     print("Invalid choice")
# ```
#
# Here we have typed `choice ==` on every condition. This is tedious and we might spell `choice` wrong, and even write a different variable in its place, causing a logic error that is hard to find.
#
# ### Introducing `match`/`case`
#
# Python 3.10 introduced the `match`/`case` statement, which provides a more elegant way to handle multiple conditions.  This is really useful when you have a single variable being compared against many potential values, like in our menu program. Here's how you can use `match`/`case` instead of if-elif-else:
#
# ```python
# match choice:
#     case 1:
#         starterMenu()
#     case 2:
#         maincourseMenu()
#     case 3:
#         dessertMenu()
#     case _:
#         print("Invalid choice")
# ```
#
# You can see that we write the variable identifier `choice` only once, so we can't mistype it later, and we save a lot of keystrokes! Instead of `if`/`elif` we have a `case` statement and write the comparison operand only (1, 2 etc). The operator `==` is assumed.  Instead of the `else` branch we use `case` with a single underscore. The above code is identical in function to the previous version that used `if-elif-else`.
#
# > **Note:** Python's `match/case` syntax is also used in Ruby, while `switch/case` is found in other programming languages such as C++, C#, Java and JavaScript.
#
# ### Benefits of `match`/`case`
#
# * **Clarity**: The `match`/`case` structure is more concise and easier to read, especially when dealing with many conditions.
#
# * **Reduced Repetition**: You only need to specify the variable once, reducing the chance of errors.
#
# * **Default Case**: The underscore (`_`) acts as a default case, similar to the `else` in `if-elif-else`.
#
# By using `match`/`case`, you can write cleaner and more maintainable code, making it a valuable tool for handling complex decision-making in your Python programs.

# %% [markdown]
# ---

# %% [markdown]
# ### Using match/case
#
# ### Understanding match/case in Python
#
# The `match/case` statement is a type of **selection** statement that allows you to compare a value against a series of values or patterns and execute code based on which pattern matches.
#
# ### Using match/case to replace if-elif-else chains:
#
# As we saw before, when you have a series of conditions that check the same variable, `match/case` can make your code cleaner and easier to read.
#
# ```python
# def getDayName(dayNumber):
#     match dayNumber:
#         case 1:
#             return "Monday"
#         case 2:
#             return "Tuesday"
#         case 3:
#             return "Wednesday"
#         case 4:
#             return "Thursday"
#         case 5:
#             return "Friday"
#         case 6:
#             return "Saturday"
#         case 7:
#             return "Sunday"
#         case _:
#             return "Invalid day"
# ```
#
# ### Handling Multiple Patterns:
#
# You can match multiple patterns in a single case using the `|` operator.
#
# ```python
# def isWeekend(dayNumber):
#     match dayNumber:
#         case 6 | 7:
#             return True
#         case _:
#             return False
# ```
#
# Here, both 6 and 7 are matched in the same case, indicating the weekend days.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu3l3_lp1_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> What will be stored in the variable day if we run this code?
day = get_day_name(2)</p>
  <input id="qu3l3_lp1_1_in" type="text" placeholder="Type your answer..."
         style="padding:4px 8px;width:50%;border:1px solid #ccc;border-radius:4px">
  <button onclick="_qchecku3l3_lp1_1()"
          style="margin-left:8px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu3l3_lp1_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu3l3_lp1_1_correct = "Tuesday";
  var _qu3l3_lp1_1_explanation = "The function returns \"Tuesday\" when the parameter is 2";
  function _qchecku3l3_lp1_1() {
    var answer = document.getElementById("qu3l3_lp1_1_in").value.trim().toLowerCase();
    var fb = document.getElementById("qu3l3_lp1_1_fb");
    if (answer === "") {
      fb.innerHTML = "<span style='color:grey'>&#128161; Answer: <b>" + _qu3l3_lp1_1_correct + "</b> &mdash; " + _qu3l3_lp1_1_explanation + "</span>";
    } else if (answer === _qu3l3_lp1_1_correct.toLowerCase()) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + _qu3l3_lp1_1_explanation + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite &mdash; try again, or clear your answer and click Check to reveal.</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Programming with match/case
#
# ### Worked Example 1: Categorising Grades
#
# In this example, we'll use the `match/case` statement to categorise grades from A to D into Distinction, Merit, Pass, and Fail. Here is a function that takes the parameter **grade** and returns a string containing the category:
#
# ```python
# def categorizeGrade(grade):
#     match grade:
#         case 'A':
#             return "Distinction"
#         case 'B':
#             return "Merit"
#         case 'C':
#             return "Pass"
#         case 'D':
#             return "Fail"
#         case _:
#             return "Invalid grade"
# ```
#
# ### Worked Example 2: Handling Multiple Conditions with |
#
# In this example, we'll use the `match/case` statement with the `|` operator to handle multiple conditions. Let's consider a scenario where we categorize weather observations into "Good", "Moderate" or "Bad":
#
# ```python
# def categorizeWeather(observation):
#     match observation:
#         case 'Sunny' | 'Clear':
#             return "Good weather"
#         case 'Cloudy' | 'Overcast':
#             return "Moderate weather"
#         case 'Rainy' | 'Stormy':
#             return "Bad weather"
#         case _:
#             return "Unknown"
# ```
#
# ## PRIMM activities
#
# Using the attached **grades.py**:
#
# 1. **🤔 Predict** what the program does.
# 2. ▶️ **Run** and check your prediction, were you correct?
# 3. 🔍 **Investigate:** why does a grade "E" or "z" return "Invalid grade"?
# 4. ✏️ **Modify:** Change the program so that "D" returns a "Level 1 Pass" and "E" and "F" both return a "Fail".
# 5. 🛠️ **Make:** a new function that is the reverse of this one, turning "Distinction" into "A" etc.

# %%
# grades.py
def categorizeGrade(grade):
    match grade:
        case 'A':
            return "Distinction"
        case 'B':
            return "Merit"
        case 'C':
            return "Pass"
        case 'D':
            return "Fail"
        case _:
            return "Invalid grade"

print(categorizeGrade("A"))

# %% [markdown]
# ---

# %% [markdown]
# ### Pseudocode notes
#
# ## Pseudocode notes on selection
#
# ![1.00](data:image/png;base64,...)
#
# For simplicity and compatibility with many languages, we do not have equivalents of `elif` or `match/case` in our pseudocode, only `IF-THEN-ELSE`.
#
# Complex conditional statements will be represented in exams with nested `IF` statements, rather than `if-elif-else` or `match-case` statements. Here is the basic structure of a nested `IF`, written in AQA pseudocode.
#
# ```python
# IF BoolExp THEN
#   # statements here
# ELSE
#   IF BoolExp THEN
#     # statements here
#   ELSE
#     # statements here
#   ENDIF
# ENDIF
# ```

# %% [markdown]
# ---

# %% [markdown]
# ### Python practical: match/case
#
# ## Using `match-case`
#
# ### 🐠 1. Animal class?
#
# Starting with the code in **q1.py**, complete the function that accepts a string representing an **animal name** and prints which **class** it belongs to: mammal, reptile, fish or bird.
#
# Use a `match-case` block to respond to the following:
#
# * If the animal is `"dog"`, print `"Mammal"`
#
# * If the animal is `"snake"`, print `"Reptile"`
#
# * If the animal is `"carp"`, print `"Fish"`
#
# * If the animal is `"eagle"`, print `"Bird"`
#
# * For any other animal, print `"Unknown"`
#
# ***
#
# ### 🚃 2. Train ticket zone checker
#
# A train station uses zones to determine ticket pricing. Starting with the code in **q2.py**, complete the function that accepts an integer representing the **zone**, (1 - 6) and returns the ticket type.
#
# Use a `match-case` block to implement the following rules:
#
# * If the zone is `1` or `2` return `"Central fare"`
#
# * If the zone is `3` or `4`, return `"Suburban fare"`
#
# * If the zone is `5` or `6`, return `"Outer fare"`
#
# * For any other zone, return `"Invalid zone"`

# %%
# q1.py
# Animal class

def classify(animal):
    match animal:
        case 'dog':
            print("Mammal") 
    # TODO - write your code here


# main program
classify("dog")       # prints "Mammal"
classify("snake")     # prints "Reptile"
classify("carp")      # prints "Fish"
classify("eagle")     # prints "Bird"
classify("capybara")  # prints "Unknown"

# %%
# q2.py
# Train ticket zone checker

def checkZone(zone):
   # write your code here


# main program
print(checkZone(1))       # prints "Central fare"
print(checkZone(2))       # prints "Central fare"
print(checkZone(4))       # prints "Suburban fare"
print(checkZone(5))       # prints "Outer fare"
print(checkZone(7))       # prints "Invalid zone"

# %% [markdown]
# ---

# %% [markdown]
# ### Solutions to match-case exercises
#
# Here is the solution to q1:
#
# ```python
# def classify(animal):
#     match animal:
#         case 'dog':
#             print("Mammal")
#         case 'snake':
#             print("Reptile")
#         case 'carp':
#             print("Fish")
#         case 'eagle':
#             print("Bird")
#         case _:
#             print("Unknown")
# ```
#
# Try it in the code editor now, using q1solution.py
#
# Here is the solution to q2:
#
# ```python
# def checkZone(zone):
#     match zone:
#         case 1 | 2:
#             return "Central fare"
#         case 3 | 4:
#             return "Suburban fare"
#         case 5 | 6:
#             return "Outer fare"
#         case _:
#             return "Invalid zone"
# ```
#
# Open the file q2solution.py to try this out.

# %%
# q1solution.py
def classify(animal):
    match animal:
        case 'dog':
            print("Mammal")
        case 'snake':
            print("Reptile")
        case 'carp':
            print("Fish")
        case 'eagle':
            print("Bird")
        case _:
            print("Unknown")

# main program
classify("dog")       # prints "Mammal"
classify("snake")     # prints "Reptile"
classify("carp")      # prints "Fish"
classify("eagle")     # prints "Bird"
classify("capybara")  # prints "Unknown"

# %%
# q2solution.py
def checkZone(zone):
    match zone:
        case 1 | 2:
            return "Central fare"
        case 3 | 4:
            return "Suburban fare"
        case 5 | 6:
            return "Outer fare"
        case _:
            return "Invalid zone"

# main program
print(checkZone(1))       # prints "Central fare"
print(checkZone(2))       # prints "Central fare"
print(checkZone(4))       # prints "Suburban fare"
print(checkZone(5))       # prints "Outer fare"
print(checkZone(7))       # prints "Invalid zone"

# %% [markdown]
# ---
