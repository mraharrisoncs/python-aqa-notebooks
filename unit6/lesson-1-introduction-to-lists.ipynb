# %% [markdown]
# # Lesson 1 - Introduction to lists
#
# Introduction to lists in Python
#
# **Learning objectives:**
# - Why use lists?
# - Basic list operations
# - Simple programming with lists
#
# ---

# %% [markdown]
# ### Why use lists?
#
# ### Why use lists?
#
# Remember our temperature program? What if - instead of just calculating a total or average and discarding our input data - we wanted to store all the input data for future use? We *could* store each day's temperature in a separate variable like this:
#
# ```python
# temp1 = int(input("Enter temperature 1: "))
# temp2 = int(input("Enter temperature 2: "))
# temp3 = int(input("Enter temperature 3: "))
# temp4 = int(input("Enter temperature 4: "))
# ''' continued
# ```
#
# But this would need one line of code and **one integer variable for each value**, and if we wanted to store the temperature *every hour for several years*, that's a lot of code and a lot of variables!
#
# Also, working with this data would need yet more clunky code, for example to sum the first seven values:
#
# ```python
# >>> total = temp1 + temp2 + temp3 + temp4 + temp5 + temp6 + temp7
# ```
#
# ## Creating and indexing a list
#
# Instead we can create a **list** called `temps` and store **all** our temperatures under this **identifier.** This is how we do that:
#
# ```python
# >>> temps = [24, 26, 31, 26, 21, 18, 22]
# ```
#
# We can now access any **item** in the list as long as we know its **position** in the list, which we call the **index** of the item. But remember from string indexing, Python always counts from **zero**. For example:
#
# ```python
# >>> temps = [24, 26, 31, 26, 21, 18, 22]
# >>> temps[0]
# 24
# >>> temps[5]
# 18
# ```
#
# Now we can use a really cool function called `sum()` to add up all the values!
#
# ```python
# >>> temps = [24, 26, 31, 26, 21, 18, 22]
# >>> sum(temps)
# 168
# ```
#
# And we can use `len()` - just like we did in string handling - to find the length of the list.
#
# ```python
# >>> temps = [24, 26, 31, 26, 21, 18, 22]
# >>> len(temps)
# 7
# ```
#
# So now we can find the **average** very easily!
#
# ```python
# >>> temps = [24, 26, 31, 26, 21, 18, 22]
# >>> sum(temps)/len(temps)
# 24.0
# ```
#
# ## About lists
#
# We chose the identifier `temps` because the list stores temperatures, making `temps` a **meaningful** name for the list. Your list identifier should say what is in the list. It's also a good idea to make a list identifier **plural** (e.g. `temps`, `scores`, `days_of_the_week`) to make clear it contains multiple items.
#
# The list is an example of a **data structure** - a way of storing and organising a collection of data under a single identifier, so it can be quickly and easily processed in many ways.
#
# ## Practice with lists
#
# Use the **Python REPL** (the Shell) on the right, and copy/paste the commands above to try them out. Then answer these questions. Use the REPL again if you're stuck.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp0_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> Why do we use lists?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_1" value="To allow us to store multiple values under a single identifier."
                 onchange="_qchecku5l0_lp0_1(this.value)"> To allow us to store multiple values under a single identifier.
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_1" value="To store only one value at a time."
                 onchange="_qchecku5l0_lp0_1(this.value)"> To store only one value at a time.
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_1" value="To make code more complex and harder to read."
                 onchange="_qchecku5l0_lp0_1(this.value)"> To make code more complex and harder to read.
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_1" value="To save memory, because lists only take up one slot in RAM"
                 onchange="_qchecku5l0_lp0_1(this.value)"> To save memory, because lists only take up one slot in RAM
        </label>
  <div id="qu5l0_lp0_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp0_1_correct = "To allow us to store multiple values under a single identifier.";
  var _qu5l0_lp0_1_explanations = {"To allow us to store multiple values under a single identifier.": "Yes, making code simpler and more elegant.", "To store only one value at a time.": "No, lists are used to store multiple values, not just one.", "To make code more complex and harder to read.": "No, lists simplify code by reducing the number of variables needed.", "To save memory, because lists only take up one slot in RAM": "No, lists do not use less memory than multiple variables."};
  function _qchecku5l0_lp0_1(val) {
    var fb = document.getElementById("qu5l0_lp0_1_fb");
    var expl = _qu5l0_lp0_1_explanations[val] || "";
    if (val === _qu5l0_lp0_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp0_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> In the list temps = [24, 26, 31, 26, 21, 18, 22], what does temps[1] return?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_2" value="24"
                 onchange="_qchecku5l0_lp0_2(this.value)"> 24
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_2" value="26"
                 onchange="_qchecku5l0_lp0_2(this.value)"> 26
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_2" value="31"
                 onchange="_qchecku5l0_lp0_2(this.value)"> 31
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_2" value="22"
                 onchange="_qchecku5l0_lp0_2(this.value)"> 22
        </label>
  <div id="qu5l0_lp0_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp0_2_correct = "26";
  var _qu5l0_lp0_2_explanations = {"24": "No, 24 is the first element, accessed with index 0.", "26": "Yes, 26 is the second element, accessed with index 1.", "31": "No, 31 is the third element, accessed with index 2.", "22": "No, 22 is the seventh element, accessed with index 6 (or -1, see later)"};
  function _qchecku5l0_lp0_2(val) {
    var fb = document.getElementById("qu5l0_lp0_2_fb");
    var expl = _qu5l0_lp0_2_explanations[val] || "";
    if (val === _qu5l0_lp0_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp0_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> If scores = [78, 64, 51], what is returned by len(scores)?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_3" value="3"
                 onchange="_qchecku5l0_lp0_3(this.value)"> 3
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_3" value="2"
                 onchange="_qchecku5l0_lp0_3(this.value)"> 2
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_3" value="1"
                 onchange="_qchecku5l0_lp0_3(this.value)"> 1
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_3" value="193"
                 onchange="_qchecku5l0_lp0_3(this.value)"> 193
        </label>
  <div id="qu5l0_lp0_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp0_3_correct = "3";
  var _qu5l0_lp0_3_explanations = {"3": "The len() function returns the number of elements in the list.", "2": "No, while the index of the last item is 2, the length of the list is 3.", "1": "No, there are three elements in the list.", "193": "No, this is the sum"};
  function _qchecku5l0_lp0_3(val) {
    var fb = document.getElementById("qu5l0_lp0_3_fb");
    var expl = _qu5l0_lp0_3_explanations[val] || "";
    if (val === _qu5l0_lp0_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp0_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> What do we call a way of storing and organising a collection of data under a single identifier?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_4" value="Data structure"
                 onchange="_qchecku5l0_lp0_4(this.value)"> Data structure
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_4" value="Variable"
                 onchange="_qchecku5l0_lp0_4(this.value)"> Variable
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_4" value="Function"
                 onchange="_qchecku5l0_lp0_4(this.value)"> Function
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp0_4" value="Algorithm"
                 onchange="_qchecku5l0_lp0_4(this.value)"> Algorithm
        </label>
  <div id="qu5l0_lp0_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp0_4_correct = "Data structure";
  var _qu5l0_lp0_4_explanations = {"Data structure": "Yes, a data structure is used to store and organize data under a single identifier.", "Variable": "No, a variable typically stores a single piece of data, not a collection.", "Function": "No, a function is a block of code that performs a specific task, not a way to store data.", "Algorithm": "No, an algorithm is a sequence of steps to solve a problem, not a way to store data."};
  function _qchecku5l0_lp0_4(val) {
    var fb = document.getElementById("qu5l0_lp0_4_fb");
    var expl = _qu5l0_lp0_4_explanations[val] || "";
    if (val === _qu5l0_lp0_4_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Creating and using lists
#
# ### Creating a list
#
# In Python, you can just assign a list to a variable like this:
#
# ```python
# temps = [24, 26, 31, 26, 21, 18, 22]
# ```
#
# Note that we use **square brackets** to indicate a list, and **elements** are separated by commas.
#
# ### Lists can contain any data type
#
# Lists can contain integers, floats, strings or Booleans, or even other lists! Here are some more example list assignments
#
# ```python
# # create a list of weights for measuring ingredients - a mix of integers and floats
# weights = [1, 2.5, 5, 7.5, 10, 15, 20, 40]
#
# # create a list of fruits as strings
# fruits = ["apple", "orange", "kiwi", "banana", "pear"]
#
# # create a student record as a mix of strings, integers, floats and Booleans
# student = ["Taha", "Hussain", 10, "Pankhurst", 104, 93.5, False]
#
# # create a list of rooms in an adventure game. Each room is another list
# # containing room number, description, object, doors and numbers of linked rooms
# rooms = [ [1, "Hall", "Mirror", "NESW", 2, 3, 4],
#           [2, "Dining Room", "Candlestick", "ESW", 1, 5, 6] ]
#
# ```
#
# That last example might be used to store the configuration of a world in a text adventure! See Unit 8 for more on **lists of lists**.
#
# ### List length
#
# The `len()` function returns the length of a list (the total number of elements).
#
# ```python
# >>> fruits = ["apple", "orange", "kiwi", "banana", "pear"]
# >>> len(fruits)
# 5
# ```
#
# ### Accessing a list item
#
# We can access an item in a list by its **index number**, the position in the list, counting from 0:
#
# ```python
# >>> fruits = ["apple", "orange", "kiwi", "banana", "pear"]
# >>> fruits[0]
# apple
#
# >>> fruits[1]
# orange
#
# >>> student = ["Taha", "Hussain", 10, "Pankhurst", 104, 93.5, False]
# >>> student[5]
# 93.5
# ```
#
# Now open the REPL and try out some of the above commands. Then try the questions below.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp1_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> Which of the following is true about data types in a Python list?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_1" value="Strings are not allowed in a Python list"
                 onchange="_qchecku5l0_lp1_1(this.value)"> Strings are not allowed in a Python list
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_1" value="Booleans are not allowed in a Python list"
                 onchange="_qchecku5l0_lp1_1(this.value)"> Booleans are not allowed in a Python list
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_1" value="Only integers and floats are allowed in a Python list"
                 onchange="_qchecku5l0_lp1_1(this.value)"> Only integers and floats are allowed in a Python list
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_1" value="Any data type can be included in a Python list"
                 onchange="_qchecku5l0_lp1_1(this.value)"> Any data type can be included in a Python list
        </label>
  <div id="qu5l0_lp1_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp1_1_correct = "Any data type can be included in a Python list";
  var _qu5l0_lp1_1_explanations = {"Strings are not allowed in a Python list": "No, any data type can be included in a Python list.", "Booleans are not allowed in a Python list": "No, any data type can be included in a Python list.", "Only integers and floats are allowed in a Python list": "No, any data type can be included in a Python list.", "Any data type can be included in a Python list": "Yes, integers, floats, Booleans, strings and other lists!"};
  function _qchecku5l0_lp1_1(val) {
    var fb = document.getElementById("qu5l0_lp1_1_fb");
    var expl = _qu5l0_lp1_1_explanations[val] || "";
    if (val === _qu5l0_lp1_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp1_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> Which of the following is the correct way to create a list of integers in Python?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_2" value="numbers = [1, 2, 3, 4, 5]"
                 onchange="_qchecku5l0_lp1_2(this.value)"> numbers = [1, 2, 3, 4, 5]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_2" value="numbers = (1, 2, 3, 4, 5)"
                 onchange="_qchecku5l0_lp1_2(this.value)"> numbers = (1, 2, 3, 4, 5)
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_2" value="numbers = {1, 2, 3, 4, 5}"
                 onchange="_qchecku5l0_lp1_2(this.value)"> numbers = {1, 2, 3, 4, 5}
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_2" value="numbers = 1, 2, 3, 4, 5"
                 onchange="_qchecku5l0_lp1_2(this.value)"> numbers = 1, 2, 3, 4, 5
        </label>
  <div id="qu5l0_lp1_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp1_2_correct = "numbers = [1, 2, 3, 4, 5]";
  var _qu5l0_lp1_2_explanations = {"numbers = [1, 2, 3, 4, 5]": "This is the correct syntax for creating a list of integers using square brackets.", "numbers = (1, 2, 3, 4, 5)": "This creates something called a tuple, not a list, because it uses parentheses.", "numbers = {1, 2, 3, 4, 5}": "This creates something called a set, not a list, because it uses curly braces.", "numbers = 1, 2, 3, 4, 5": "This creates a tuple by default, not a list, because it lacks square brackets."};
  function _qchecku5l0_lp1_2(val) {
    var fb = document.getElementById("qu5l0_lp1_2_fb");
    var expl = _qu5l0_lp1_2_explanations[val] || "";
    if (val === _qu5l0_lp1_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp1_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> Using the list fruits = ["apple", "orange", "kiwi", "banana", "pear"], which command would display "kiwi"?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_3" value="fruits[2]"
                 onchange="_qchecku5l0_lp1_3(this.value)"> fruits[2]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_3" value="fruits[0]"
                 onchange="_qchecku5l0_lp1_3(this.value)"> fruits[0]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_3" value="fruits[1]"
                 onchange="_qchecku5l0_lp1_3(this.value)"> fruits[1]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp1_3" value="fruits[3]"
                 onchange="_qchecku5l0_lp1_3(this.value)"> fruits[3]
        </label>
  <div id="qu5l0_lp1_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp1_3_correct = "fruits[2]";
  var _qu5l0_lp1_3_explanations = {"fruits[2]": "Yes, 'kiwi' is at index 2 in the list.", "fruits[0]": "No, 'apple' is at index 0 in the list.", "fruits[1]": "No, 'orange' is at index 1 in the list (because we count from 0)", "fruits[3]": "No, 'banana' is at index 3 in the list (because we count from 0)"};
  function _qchecku5l0_lp1_3(val) {
    var fb = document.getElementById("qu5l0_lp1_3_fb");
    var expl = _qu5l0_lp1_3_explanations[val] || "";
    if (val === _qu5l0_lp1_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp1_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> What is the index number used to access the first element of a list in Python?</p>
  <input id="qu5l0_lp1_4_in" type="text" placeholder="Type your answer..."
         style="padding:4px 8px;width:50%;border:1px solid #ccc;border-radius:4px">
  <button onclick="_qchecku5l0_lp1_4()"
          style="margin-left:8px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu5l0_lp1_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp1_4_correct = "0";
  var _qu5l0_lp1_4_explanation = "Yes, in Python, list indexing starts at 0.";
  function _qchecku5l0_lp1_4() {
    var answer = document.getElementById("qu5l0_lp1_4_in").value.trim().toLowerCase();
    var fb = document.getElementById("qu5l0_lp1_4_fb");
    if (answer === "") {
      fb.innerHTML = "<span style='color:grey'>&#128161; Answer: <b>" + _qu5l0_lp1_4_correct + "</b> &mdash; " + _qu5l0_lp1_4_explanation + "</span>";
    } else if (answer === _qu5l0_lp1_4_correct.toLowerCase()) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + _qu5l0_lp1_4_explanation + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite &mdash; try again, or clear your answer and click Check to reveal.</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp1_5" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q5.</b> Given the list student = ["Taha", "Hussain", 10, "Pankhurst", 104, 93.5, False], type the command that retrieves the student's surname "Hussain".</p>
  <input id="qu5l0_lp1_5_in" type="text" placeholder="Type your answer..."
         style="padding:4px 8px;width:50%;border:1px solid #ccc;border-radius:4px">
  <button onclick="_qchecku5l0_lp1_5()"
          style="margin-left:8px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu5l0_lp1_5_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp1_5_correct = "student[1]";
  var _qu5l0_lp1_5_explanation = "Yes, the surname \"Hussain\" is at index 1 in the list.";
  function _qchecku5l0_lp1_5() {
    var answer = document.getElementById("qu5l0_lp1_5_in").value.trim().toLowerCase();
    var fb = document.getElementById("qu5l0_lp1_5_fb");
    if (answer === "") {
      fb.innerHTML = "<span style='color:grey'>&#128161; Answer: <b>" + _qu5l0_lp1_5_correct + "</b> &mdash; " + _qu5l0_lp1_5_explanation + "</span>";
    } else if (answer === _qu5l0_lp1_5_correct.toLowerCase()) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + _qu5l0_lp1_5_explanation + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite &mdash; try again, or clear your answer and click Check to reveal.</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### List slicing
#
# You've seen how to access individual elements in a list using their index positions. What if we want a sequence of more than one element, e.g. the first three or the last two?
#
# ## List slicing
#
# The basic Python syntax for **list slicing**, is this:
#
# ```python
# identifier[start : end]
# ```
#
# where **identifier** is our variable name, **start** is the starting position of the sequence, and **end** is the first element we **don't want!**
#
# > *Tip:* The syntax we use for list slicing syntax is identical to **string slicing** syntax. All the tricks we learned in **string slicing** can be used with lists too!
#
# Just like in string slicing, we must make the second value **one more** than the last element we want to extract.
#
# ### Structure of a list
#
# Here is that **fruits** list again, showing the index of each element:
#
# ```
# fruits
# +--------+--------+--------+--------+--------+--------+
# | index  |   0    |   1    |   2    |   3    |   4    |
# +--------+--------+--------+--------+--------+--------+
# | value  | apple  | orange |  kiwi  | banana |  pear  |
# +--------+--------+--------+--------+--------+--------+
# ```
#
# ### Indexing from the start
#
# We've seen already we can access individual elements by their index position, counting from zero:
#
# ```python
# >>> fruits = ["apple", "orange", "kiwi", "banana", "pear"]
# >>> fruits[2]
# 'kiwi'
# ```
#
# ### Indexing from the end
#
# We can also count backwards **from the end of the list** using negative numbers. Index `-1` indicates the last element, `-2` the second last, and so on:
#
# ```python
# >>> fruits = ["apple", "orange", "kiwi", "banana", "pear"]
# >>> fruits[-1]
# 'pear'
#
# >>> fruits[-2]
# 'banana'
#
# ```
#
# Here we can see the negative indexes, underneath the usual positive indexes:
#
# ```
# fruits
# +----------+--------+--------+--------+--------+--------+
# | index    |   0    |   1    |   2    |   3    |   4    |
# +----------+--------+--------+--------+--------+--------+
# | negative |   -5   |   -4   |   -3   |   -2   |   -1   |
# +----------+--------+--------+--------+--------+--------+
# | value    | apple  | orange |  kiwi  | banana |  pear  |
# +----------+--------+--------+--------+--------+--------+
# ```
#
# ### List slicing
#
# We can also give both **start** and **end** values, to retrieve a **list slice**. This behaves in the same way as **string slicing** (see Unit 3), we give the **start** index, and the index of the first element we **do not want**, as the **end** index. Here is how that works:
#
# ```python
# >>> fruits = ["apple", "orange", "kiwi", "banana", "pear"]
# >>> fruits[0:2]
# ['apple', 'orange']
#
# >>> fruits[2:5]
# ['kiwi', 'banana', 'pear']
#
# ```
#
# If we leave either **start** or **end** value blank, Python will assume we mean the start or end of the list:
#
# ```python
# >>> fruits = ["apple", "orange", "kiwi", "banana", "pear"]
# >>> fruits[:2]
# ['apple', 'orange']
#
# >>> fruits[3:]
# ['banana', 'pear']
#
# ```
#
# We can use negative numbers in our slice too, here's how to chop off the final element:
#
# ```python
# >>> fruits[:-1]
# ['apple', 'orange', 'kiwi', 'banana']
# ```
#
# Now use the REPL on the right to practice list slicing, and answer the following questions.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp2_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> Given the list fruits = ["apple", "orange", "kiwi", "banana", "pear"] choose the command that retrieves ['apple', 'orange']</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp2_1" value="fruits[0:2]"
                 onchange="_qchecku5l0_lp2_1(this.value)"> fruits[0:2]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp2_1" value="fruits[0:1]"
                 onchange="_qchecku5l0_lp2_1(this.value)"> fruits[0:1]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp2_1" value="fruits[1:3]"
                 onchange="_qchecku5l0_lp2_1(this.value)"> fruits[1:3]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp2_1" value="fruits[:1]"
                 onchange="_qchecku5l0_lp2_1(this.value)"> fruits[:1]
        </label>
  <div id="qu5l0_lp2_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp2_1_correct = "fruits[0:2]";
  var _qu5l0_lp2_1_explanations = {"fruits[0:2]": "Yes, this command slices the list from index 0 to 2, excluding index 2.", "fruits[0:1]": "No, this command retrieves only the first element, 'apple'.", "fruits[1:3]": "No, this command retrieves 'orange' and 'kiwi'.", "fruits[:1]": "No, this command retrieves only the first element, 'apple'."};
  function _qchecku5l0_lp2_1(val) {
    var fb = document.getElementById("qu5l0_lp2_1_fb");
    var expl = _qu5l0_lp2_1_explanations[val] || "";
    if (val === _qu5l0_lp2_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp2_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> Given the list fruits = ["apple", "orange", "kiwi", "banana", "pear"] choose the command that retrieves ['banana', 'pear']</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp2_2" value="fruits[3:5]"
                 onchange="_qchecku5l0_lp2_2(this.value)"> fruits[3:5]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp2_2" value="fruits[2:4]"
                 onchange="_qchecku5l0_lp2_2(this.value)"> fruits[2:4]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp2_2" value="fruits[-2:]"
                 onchange="_qchecku5l0_lp2_2(this.value)"> fruits[-2:]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp2_2" value="fruits[4:]"
                 onchange="_qchecku5l0_lp2_2(this.value)"> fruits[4:]
        </label>
  <div id="qu5l0_lp2_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp2_2_correct = "fruits[3:5]";
  var _qu5l0_lp2_2_explanations = {"fruits[3:5]": "Yes, this slice starts at index 3 and ends at index 5, retrieving 'banana' and 'pear'.", "fruits[2:4]": "No, this slice retrieves 'kiwi' and 'banana', not 'banana' and 'pear'.", "fruits[-2:]": "No, this slice retrieves 'kiwi', 'banana', and 'pear', not just 'banana' and 'pear'.", "fruits[4:]": "No, this slice retrieves 'pear', only"};
  function _qchecku5l0_lp2_2(val) {
    var fb = document.getElementById("qu5l0_lp2_2_fb");
    var expl = _qu5l0_lp2_2_explanations[val] || "";
    if (val === _qu5l0_lp2_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp2_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> Given the list fruits = ["apple", "orange", "kiwi", "banana", "pear"] choose all the commands that retrieve ['kiwi', 'banana', 'pear'].<br><i style="font-size:0.9em">Select all that apply.</i></p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="checkbox" id="qu5l0_lp2_3_cb0" value="fruits[2:5]"> fruits[2:5]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="checkbox" id="qu5l0_lp2_3_cb1" value="fruits[-3:]"> fruits[-3:]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="checkbox" id="qu5l0_lp2_3_cb2" value="fruits[3:5]"> fruits[3:5]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="checkbox" id="qu5l0_lp2_3_cb3" value="fruits[1:4]"> fruits[1:4]
        </label>
  <button onclick="_qchecku5l0_lp2_3()"
          style="margin-top:10px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu5l0_lp2_3_fb" style="margin-top:8px"></div>
</div>
<script>
  var _qu5l0_lp2_3_correct = ["fruits[-3:]", "fruits[2:5]"];
  var _qu5l0_lp2_3_explanations = {"fruits[2:5]": "Yes, fruits[2:5] correctly slices the list from index 2 to 4.", "fruits[-3:]": "Yes, fruits[-3:] correctly slices the list from index -3 to the end.", "fruits[3:5]": "No, fruits[3:5] retrieves ['banana', 'pear'], not ['kiwi', 'banana', 'pear'].", "fruits[1:4]": "No, fruits[1:4] retrieves ['orange', 'kiwi', 'banana'], not ['kiwi', 'banana', 'pear']."};
  var _qu5l0_lp2_3_cbids = ["qu5l0_lp2_3_cb0", "qu5l0_lp2_3_cb1", "qu5l0_lp2_3_cb2", "qu5l0_lp2_3_cb3"];
  function _qchecku5l0_lp2_3() {
    var selected = _qu5l0_lp2_3_cbids
      .map(function(id) { return document.getElementById(id); })
      .filter(function(cb) { return cb.checked; })
      .map(function(cb) { return cb.value; })
      .sort();
    var lines = [];
    ["fruits[2:5]", "fruits[-3:]", "fruits[3:5]", "fruits[1:4]"].forEach(function(opt) {
      var expl = _qu5l0_lp2_3_explanations[opt] || "";
      var isCorrect = _qu5l0_lp2_3_correct.indexOf(opt) !== -1;
      var isSelected = selected.indexOf(opt) !== -1;
      if (isCorrect && isSelected)
        lines.push("<div style='color:green'>&#10003; <b>" + opt + "</b> &mdash; " + expl + "</div>");
      else if (isCorrect && !isSelected)
        lines.push("<div style='color:orange'>&#9651; <b>" + opt + "</b> &mdash; you missed this. " + expl + "</div>");
      else if (!isCorrect && isSelected)
        lines.push("<div style='color:crimson'>&#10007; <b>" + opt + "</b> &mdash; " + expl + "</div>");
    });
    var allRight = JSON.stringify(selected) === JSON.stringify(_qu5l0_lp2_3_correct);
    if (allRight) lines.unshift("<div style='color:green;font-weight:bold'>All correct! &#127881;</div>");
    document.getElementById("qu5l0_lp2_3_fb").innerHTML = lines.join("");
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp2_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> Given a list called fruits, write the simplest command that retrieves the list without it's final element, no matter the length of the list.</p>
  <input id="qu5l0_lp2_4_in" type="text" placeholder="Type your answer..."
         style="padding:4px 8px;width:50%;border:1px solid #ccc;border-radius:4px">
  <button onclick="_qchecku5l0_lp2_4()"
          style="margin-left:8px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu5l0_lp2_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp2_4_correct = "fruits[:-1]";
  var _qu5l0_lp2_4_explanation = "Using fruits[:-1] always slices the list from the start to the second last element.";
  function _qchecku5l0_lp2_4() {
    var answer = document.getElementById("qu5l0_lp2_4_in").value.trim().toLowerCase();
    var fb = document.getElementById("qu5l0_lp2_4_fb");
    if (answer === "") {
      fb.innerHTML = "<span style='color:grey'>&#128161; Answer: <b>" + _qu5l0_lp2_4_correct + "</b> &mdash; " + _qu5l0_lp2_4_explanation + "</span>";
    } else if (answer === _qu5l0_lp2_4_correct.toLowerCase()) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + _qu5l0_lp2_4_explanation + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite &mdash; try again, or clear your answer and click Check to reveal.</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp2_5" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q5.</b> Given a list called fruits with at least three elements, write the simplest command that returns the list without its first two elements, no matter the length of the list.</p>
  <input id="qu5l0_lp2_5_in" type="text" placeholder="Type your answer..."
         style="padding:4px 8px;width:50%;border:1px solid #ccc;border-radius:4px">
  <button onclick="_qchecku5l0_lp2_5()"
          style="margin-left:8px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu5l0_lp2_5_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp2_5_correct = "fruits[2:]";
  var _qu5l0_lp2_5_explanation = "Using fruits[2:] slices the list from the third element to the end.";
  function _qchecku5l0_lp2_5() {
    var answer = document.getElementById("qu5l0_lp2_5_in").value.trim().toLowerCase();
    var fb = document.getElementById("qu5l0_lp2_5_fb");
    if (answer === "") {
      fb.innerHTML = "<span style='color:grey'>&#128161; Answer: <b>" + _qu5l0_lp2_5_correct + "</b> &mdash; " + _qu5l0_lp2_5_explanation + "</span>";
    } else if (answer === _qu5l0_lp2_5_correct.toLowerCase()) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + _qu5l0_lp2_5_explanation + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite &mdash; try again, or clear your answer and click Check to reveal.</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Append, change and remove list items
#
# ### Append to a list
#
# Lists can grow and shrink: they are not fixed in size. We can add items to the end of the list using the `append` method. Here is an example:
#
# ```python
# >>> fruits = ["apple", "orange", "kiwi", "banana", "pear"]
# >>> fruits.append("plum")
# >>> fruits
# ['apple', 'orange', 'kiwi', 'banana', 'pear', 'plum']
# ```
#
# ### Change list element
#
# We can change or **overwrite** a list element by using its index, like this:
#
# ```python
# >>> fruits[1] = "peach"
# >>> fruits
# ['apple', 'peach', 'kiwi', 'banana', 'pear', 'plum']
# ```
#
# You can see that element with index 1 has changed from "orange" to "peach".
#
# ### Remove list element
#
# The `remove` method can find and remove a list item by name:
#
# ```python
# >>> fruits = ['apple', 'peach', 'kiwi', 'banana', 'pear', 'plum']
# >>> fruits.remove("kiwi")
# >>> fruits
# ['apple', 'peach', 'banana', 'pear', 'plum']
# ```
#
# Note that `remove` gets rid of the **first** matching element only:
#
# ```python
# >>> planets = ["Mercury", "Venus", "Venus", "Earth", "Venus"]
# >>> planets.remove("Venus")
# >>> planets
# ['Mercury', 'Venus', 'Earth', 'Venus']
# ```
#
# We can also delete items by index number with the `del` command:
#
# ```python
# >>> planets = ["Mercury", "Venus", "Earth", "Venus"]
# >>> del planets[3]
# >>> planets
# ['Mercury', 'Venus', 'Earth']
# ```
#
# Try out the above commands in the REPL now, and then answer these questions.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp3_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> Which method would you use to add an item to the end of a list in Python?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_1" value="append"
                 onchange="_qchecku5l0_lp3_1(this.value)"> append
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_1" value="remove"
                 onchange="_qchecku5l0_lp3_1(this.value)"> remove
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_1" value="add"
                 onchange="_qchecku5l0_lp3_1(this.value)"> add
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_1" value="len"
                 onchange="_qchecku5l0_lp3_1(this.value)"> len
        </label>
  <div id="qu5l0_lp3_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp3_1_correct = "append";
  var _qu5l0_lp3_1_explanations = {"append": "Yes, the append method adds an item to the end of a list.", "remove": "No, the remove method deletes an item from a list.", "add": "No, add is not a list method.", "len": "No, the len function returns the length of the list."};
  function _qchecku5l0_lp3_1(val) {
    var fb = document.getElementById("qu5l0_lp3_1_fb");
    var expl = _qu5l0_lp3_1_explanations[val] || "";
    if (val === _qu5l0_lp3_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp3_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> If we start with dogs = ["pug", "spaniel"] and then execute dogs.append("poodle"), what is the state of the dogs list?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_2" value="[&quot;pug&quot;, &quot;spaniel&quot;, &quot;poodle&quot;]"
                 onchange="_qchecku5l0_lp3_2(this.value)"> ["pug", "spaniel", "poodle"]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_2" value="[&quot;poodle&quot;, &quot;pug&quot;, &quot;spaniel&quot;]"
                 onchange="_qchecku5l0_lp3_2(this.value)"> ["poodle", "pug", "spaniel"]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_2" value="[&quot;pug&quot;, &quot;spanielpoodle&quot;]"
                 onchange="_qchecku5l0_lp3_2(this.value)"> ["pug", "spanielpoodle"]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_2" value="[&quot;pug&quot;, &quot;spaniel&quot;]"
                 onchange="_qchecku5l0_lp3_2(this.value)"> ["pug", "spaniel"]
        </label>
  <div id="qu5l0_lp3_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp3_2_correct = "[\"pug\", \"spaniel\", \"poodle\"]";
  var _qu5l0_lp3_2_explanations = {"[\"pug\", \"spaniel\", \"poodle\"]": "Yes, the append method adds the item to the end of the list.", "[\"poodle\", \"pug\", \"spaniel\"]": "No, append does not add the item to the front of the list.", "[\"pug\", \"spanielpoodle\"]": "No, append does not join the string to an existing element in the list.", "[\"pug\", \"spaniel\"]": "No, append adds an item to the list, so the list will have an additional element."};
  function _qchecku5l0_lp3_2(val) {
    var fb = document.getElementById("qu5l0_lp3_2_fb");
    var expl = _qu5l0_lp3_2_explanations[val] || "";
    if (val === _qu5l0_lp3_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp3_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> If we start with dogs = ["pug", "spaniel", "poodle"], and we want to get rid of "pug" leaving ["spaniel", "poodle"], which two commands would work here?<br><i style="font-size:0.9em">Select all that apply.</i></p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="checkbox" id="qu5l0_lp3_3_cb0" value="dogs.remove(&quot;pug&quot;)"> dogs.remove("pug")
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="checkbox" id="qu5l0_lp3_3_cb1" value="del dogs[0]"> del dogs[0]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="checkbox" id="qu5l0_lp3_3_cb2" value="dogs.append(&quot;pug&quot;)"> dogs.append("pug")
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="checkbox" id="qu5l0_lp3_3_cb3" value="dogs[0] = &quot;&quot;"> dogs[0] = ""
        </label>
  <button onclick="_qchecku5l0_lp3_3()"
          style="margin-top:10px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu5l0_lp3_3_fb" style="margin-top:8px"></div>
</div>
<script>
  var _qu5l0_lp3_3_correct = ["del dogs[0]", "dogs.remove(\"pug\")"];
  var _qu5l0_lp3_3_explanations = {"dogs.remove(\"pug\")": "The remove method deletes the specified item from the list.", "del dogs[0]": "Yes, the del statement removes the item at the specified index.", "dogs.append(\"pug\")": "No, the append method adds an item to the end of the list, it doesn't remove it.", "dogs[0] = \"\"": "No, this command changes the first item to an empty list but it remains in the list"};
  var _qu5l0_lp3_3_cbids = ["qu5l0_lp3_3_cb0", "qu5l0_lp3_3_cb1", "qu5l0_lp3_3_cb2", "qu5l0_lp3_3_cb3"];
  function _qchecku5l0_lp3_3() {
    var selected = _qu5l0_lp3_3_cbids
      .map(function(id) { return document.getElementById(id); })
      .filter(function(cb) { return cb.checked; })
      .map(function(cb) { return cb.value; })
      .sort();
    var lines = [];
    ["dogs.remove(\"pug\")", "del dogs[0]", "dogs.append(\"pug\")", "dogs[0] = \"\""].forEach(function(opt) {
      var expl = _qu5l0_lp3_3_explanations[opt] || "";
      var isCorrect = _qu5l0_lp3_3_correct.indexOf(opt) !== -1;
      var isSelected = selected.indexOf(opt) !== -1;
      if (isCorrect && isSelected)
        lines.push("<div style='color:green'>&#10003; <b>" + opt + "</b> &mdash; " + expl + "</div>");
      else if (isCorrect && !isSelected)
        lines.push("<div style='color:orange'>&#9651; <b>" + opt + "</b> &mdash; you missed this. " + expl + "</div>");
      else if (!isCorrect && isSelected)
        lines.push("<div style='color:crimson'>&#10007; <b>" + opt + "</b> &mdash; " + expl + "</div>");
    });
    var allRight = JSON.stringify(selected) === JSON.stringify(_qu5l0_lp3_3_correct);
    if (allRight) lines.unshift("<div style='color:green;font-weight:bold'>All correct! &#127881;</div>");
    document.getElementById("qu5l0_lp3_3_fb").innerHTML = lines.join("");
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp3_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> Given the list colours = ["red", "purple", "blue", "cyan", "green", "yellow", "orange"], which command changes "purple" to "magenta"?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_4" value="colours[1] = &quot;magenta&quot;"
                 onchange="_qchecku5l0_lp3_4(this.value)"> colours[1] = "magenta"
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_4" value="colours.append(&quot;magenta&quot;)"
                 onchange="_qchecku5l0_lp3_4(this.value)"> colours.append("magenta")
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_4" value="colours.remove(&quot;purple&quot;)"
                 onchange="_qchecku5l0_lp3_4(this.value)"> colours.remove("purple")
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_4" value="colours[2] = &quot;magenta&quot;"
                 onchange="_qchecku5l0_lp3_4(this.value)"> colours[2] = "magenta"
        </label>
  <div id="qu5l0_lp3_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp3_4_correct = "colours[1] = \"magenta\"";
  var _qu5l0_lp3_4_explanations = {"colours[1] = \"magenta\"": "This command correctly accesses the index of \"purple\" and changes it to \"magenta\".", "colours.append(\"magenta\")": "No, this command adds \"magenta\" to the end of the list, it does not replace \"purple\".", "colours.remove(\"purple\")": "No, this command removes \"purple\" from the list but does not replace it with \"magenta\".", "colours[2] = \"magenta\"": "No, this command accesses the index of \"blue\" and changes it to \"magenta\"."};
  function _qchecku5l0_lp3_4(val) {
    var fb = document.getElementById("qu5l0_lp3_4_fb");
    var expl = _qu5l0_lp3_4_explanations[val] || "";
    if (val === _qu5l0_lp3_4_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp3_5" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q5.</b> Given the list colours = ["red", "purple", "red", "purple"], what would be in the list after the command colours.remove("purple")?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_5" value="[&quot;red&quot;, &quot;red&quot;, &quot;purple&quot;]"
                 onchange="_qchecku5l0_lp3_5(this.value)"> ["red", "red", "purple"]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_5" value="[&quot;red&quot;, &quot;purple&quot;, &quot;red&quot;]"
                 onchange="_qchecku5l0_lp3_5(this.value)"> ["red", "purple", "red"]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_5" value="[&quot;red&quot;, &quot;red&quot;]"
                 onchange="_qchecku5l0_lp3_5(this.value)"> ["red", "red"]
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp3_5" value="[&quot;red&quot;, &quot;purple&quot;, &quot;purple&quot;]"
                 onchange="_qchecku5l0_lp3_5(this.value)"> ["red", "purple", "purple"]
        </label>
  <div id="qu5l0_lp3_5_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp3_5_correct = "[\"red\", \"red\", \"purple\"]";
  var _qu5l0_lp3_5_explanations = {"[\"red\", \"red\", \"purple\"]": "Yes, the remove method deletes the first occurrence of \"purple\".", "[\"red\", \"purple\", \"red\"]": "No, the first \"purple\" is removed, not the last.", "[\"red\", \"red\"]": "No, only the first \"purple\" is removed, not all occurrences.", "[\"red\", \"purple\", \"purple\"]": "No, the first \"purple\" is removed, leaving one \"purple\"."};
  function _qchecku5l0_lp3_5(val) {
    var fb = document.getElementById("qu5l0_lp3_5_fb");
    var expl = _qu5l0_lp3_5_explanations[val] || "";
    if (val === _qu5l0_lp3_5_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### List membership - index and in
#
# ### Finding items in a list
#
# We can find the position of an item in a list with the `index()` method. This returns the index of the first item that matches the argument:
#
# ```python
# >>> planets = ["Mercury", "Venus", "Venus", "Earth", "Venus"]
# >>> planets.index("Venus")
# 1
#
# >>> colours = ["red", "magenta", "blue", "cyan", "green", "yellow", "orange"]
# >>> colours.index("yellow")
# 5
#
# ```
#
# If the item is not in the list, the instruction will fail with a Python `ValueError`:
#
# ```python
# >>> pets = ["dog", "cat", "hamster"]
# >>> pets.index("gecko")
# ValueError
# ```
#
# ### Check item in list
#
# Just like we did with strings, we can check whether an item is in a list with the `in` operator:
#
# ```python
# >>> pets = ["dog", "cat", "hamster"]
# >>> "dog" in pets
# True
# >>> "gecko" in pets
# False
# ```
#
# Try these out in the REPL now, then answer these questions.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp4_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> Given the list colours = ["red", "magenta", "blue", "cyan", "green", "yellow", "orange"], what instruction would return the position of "green" in the list?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_1" value="colours.index(&quot;green&quot;)"
                 onchange="_qchecku5l0_lp4_1(this.value)"> colours.index("green")
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_1" value="colours.index(&quot;yellow&quot;)"
                 onchange="_qchecku5l0_lp4_1(this.value)"> colours.index("yellow")
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_1" value="&quot;green&quot; in colours"
                 onchange="_qchecku5l0_lp4_1(this.value)"> "green" in colours
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_1" value="colours[4]"
                 onchange="_qchecku5l0_lp4_1(this.value)"> colours[4]
        </label>
  <div id="qu5l0_lp4_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp4_1_correct = "colours.index(\"green\")";
  var _qu5l0_lp4_1_explanations = {"colours.index(\"green\")": "Yes, this returns the index of \"green\" in the list.", "colours.index(\"yellow\")": "No, this returns the index of \"yellow\", not \"green\".", "\"green\" in colours": "No, this checks if \"green\" is in the list but does not return it.", "colours[4]": "No, this returns the item at index 4, which is \"green\", but does not return the index method."};
  function _qchecku5l0_lp4_1(val) {
    var fb = document.getElementById("qu5l0_lp4_1_fb");
    var expl = _qu5l0_lp4_1_explanations[val] || "";
    if (val === _qu5l0_lp4_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp4_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> Given the list colours = ["red", "magenta", "blue", "cyan", "green", "yellow", "orange"], what would be the result of colours.index("purple")?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_2" value="ValueError"
                 onchange="_qchecku5l0_lp4_2(this.value)"> ValueError
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_2" value="0"
                 onchange="_qchecku5l0_lp4_2(this.value)"> 0
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_2" value="6"
                 onchange="_qchecku5l0_lp4_2(this.value)"> 6
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_2" value="-1"
                 onchange="_qchecku5l0_lp4_2(this.value)"> -1
        </label>
  <div id="qu5l0_lp4_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp4_2_correct = "ValueError";
  var _qu5l0_lp4_2_explanations = {"ValueError": "Yes, because 'purple' is not in the list, so a ValueError is raised.", "0": "No, because 'purple' is not the first item in the list.", "6": "No, because 'purple' is not in the list.", "-1": "No, because Python raises a ValueError instead of returning -1 when an item is not found."};
  function _qchecku5l0_lp4_2(val) {
    var fb = document.getElementById("qu5l0_lp4_2_fb");
    var expl = _qu5l0_lp4_2_explanations[val] || "";
    if (val === _qu5l0_lp4_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu5l0_lp4_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> Given a list of strings with identifier colours, how can we check if the string 'green' is in the list?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_3" value="'green' in colours"
                 onchange="_qchecku5l0_lp4_3(this.value)"> 'green' in colours
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_3" value="colours.index('green')"
                 onchange="_qchecku5l0_lp4_3(this.value)"> colours.index('green')
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_3" value="colours.contains('green')"
                 onchange="_qchecku5l0_lp4_3(this.value)"> colours.contains('green')
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu5l0_lp4_3" value="'green' == colours"
                 onchange="_qchecku5l0_lp4_3(this.value)"> 'green' == colours
        </label>
  <div id="qu5l0_lp4_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu5l0_lp4_3_correct = "'green' in colours";
  var _qu5l0_lp4_3_explanations = {"'green' in colours": "Yes, the 'in' operator checks for membership in the list.", "colours.index('green')": "No, this returns the index of 'green' if it exists, but raises an error if it doesn't.", "colours.contains('green')": "No, 'contains' is not a valid method for lists in Python.", "'green' == colours": "No, this checks if 'green' is equal to the entire list, not if it's in the list."};
  function _qchecku5l0_lp4_3(val) {
    var fb = document.getElementById("qu5l0_lp4_3_fb");
    var expl = _qu5l0_lp4_3_explanations[val] || "";
    if (val === _qu5l0_lp4_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Programming with lists
#
# ## 🌡️ Worked Example 1 - Average Temperature
#
# Here is the average temperature program again. This time we are going to pass
# a list of temperatures to the function.
#
# ```python
#
# def analyseTemps(temps):
#     total = 0
#     index = 0
#     while index < len(temps):
#         total += temps[index]
#
#     return total / len(temps)
#
# # MAIN PROGRAM
#
# average = analyseTemps([21.1, 23.4, 26.9, 24.1, 25.5, 29.0, 27.8])
#
# print("Average temperature was:", average)
#
# ```
#
# #### Explanation
#
# 1. `def analyse_temps(temps):` - This line defines a function named
#    `analyse_temps` that takes one parameter, `temps`, which is expected to be a
#    list of temperature values.
#
# 2. `total = 0` - Initializes a variable `total` to 0. This variable will be
#    used to accumulate the sum of all temperatures in the list.
#
# 3. `index = 0` - Initializes a variable `index` to 0. This variable will be
#    used to keep track of the current position in the list as we iterate through
#    it.
#
# 4. `while index < len(temps):` - Starts a while loop that will continue as
#    long as `index` is less than the length of the `temps` list. This ensures that
#    we process each temperature in the list.
#
# 5. `total += temps[index]` - This line adds the current temperature to
#    `total`.
#
# 6. `index += 1` - Increments the `index` variable by 1, moving to the next
#    position in the list for the next iteration of the loop.
#
# 7. `return total / len(temps)` - After the loop has processed all
#    temperatures, this line calculates the average temperature by dividing the
#    `total` sum by the number of temperatures in the list (`len(temps)`) and
#    returns the result.
#
# ***
#
# ## 🗨️ Worked Example 2 - Validating a language choice
#
# ```python
# def getLanguage():
#     supportedLanguages = ["English", "French", "Spanish", "Arabic"]:
#     looping = True
#     while looping:
#         language = input("Please select a language: ")
#         if language in supportedLanguages
#             looping = False
#         else:
#             print("Invalid input, try again!")
#     return language
# ```
#
# #### Explanation
#
# This code defines a function `get_language()` that helps users select a language from a predefined list. Let's break it down line by line:
#
# 1. `def get_language():` - This line defines a function named `get_language` that takes no parameters.
# 2. `supported_languages = ["English", "French", "Spanish", "Arabic"]:` - Initializes a list called `supported_languages` containing the languages that the user can select.
# 3. `looping = True` - Sets a boolean variable `looping` to `True`, which will control the while loop.
# 4. `while looping:` - Begins a while loop that will continue to execute as long as `looping` is `True`.
# 5. `language = input("Please select a language: ")` - Prompts the user to input a language and stores the input in the variable `language`.
# 6. `if language in supported_languages` - Checks if the user's input is in the `supported_languages` list.
# 7. `looping = False` - If the input is valid, sets `looping` to `False`, which will exit the loop.
# 8. `else:` - If the input is not valid, the code proceeds to the next line.
# 9. `print("Invalid input, try again!")` - Informs the user that the input was invalid and prompts them to try again.
# 10. `return language` - Once a valid language is selected, the function returns the selected language.
#
# ***
#
# ## 📜 PRIMM Activity - Shopping List Program
#
# ```python
# # Shopping List Program
#
# def addItem(shoppingList, item):
#     shoppingList.append(item)
#     print(f"Added {item} to the shopping list.")
#
# def removeItem(shoppingList, item):
#     if item in shoppingList:
#         shoppingList.remove(item)
#         print(f"Removed {item} from the shopping list.")
#     else:
#         print(f"{item} not found in the shopping list.")
#
# def displayList(shoppingList):
#     print("Shopping List:")
#     print(shoppingList)
#
# # MAIN PROGRAM
# shoppingList = []
#
# addItem(shoppingList, "Apples")
# addItem(shoppingList, "Bananas")
# displayList(shoppingList)
# removeItem(shoppingList, "Bananas")
# displayList(shoppingList)
# ```
#
# 1. 🤔 **Predict** what the program does.
#
# 2. ▶️ **Run** and check your prediction, were you correct?
#
# 3. 🔍 **Investigate**:
#
#    * What variable is used to store the list of items, and what is its data type?
#
#    * What is the purpose of the `add_item() `function?
#
#    * In the function `remove_item()`, what is the purpose of the line `if item in shopping_list`?
#
# 4. ✏️ **Modify**:
#
#    * Change the program to allow only unique items in the shopping list.
#
#    * **Stretch challenge**: Add a feature to sort the list alphabetically before displaying it. Hint, use `<string>.sort()`
#
# 5. 🛠️ **Make**: Using the starter code in **text\_editor.py**, write a basic text editor with the following features:
#
#    * `add_line(text)`: Adds a line at the end of the document containing the text
#
#    * `display_doc()`: Displays all lines in the document with line numbers
#
#    * `remove_line(num)`: Removes a numbered line from the document.

# %%
# shopping_list_app.py
# Shopping List Program

def addItem(shoppingList, item):
    shoppingList.append(item)
    print(f"Added {item} to the shopping list.")

def removeItem(shoppingList, item):
    if item in shoppingList:
        shoppingList.remove(item)
        print(f"Removed {item} from the shopping list.")
    else:
        print(f"{item} not found in the shopping list.")

def displayList(shoppingList):
    print("Shopping List:")
    print(shoppingList)

# MAIN PROGRAM
shoppingList = []

addItem(shoppingList, "Apples")
addItem(shoppingList, "Bananas")
displayList(shoppingList)
removeItem(shoppingList, "Bananas")
displayList(shoppingList)

# %%
# text_editor.py
# Text Editor Program

def add_line(document, text):
    # TODO: Add the text to the end of the document list
    pass


def display_doc(document):
    # TODO: Display all lines with line numbers
    pass


def remove_line(document, num):
    # TODO: Remove the line at position num (if it exists)
    pass


# MAIN PROGRAM
document = []

# Example calls (students can change these)
add_line(document, "This is the first line.")
add_line(document, "This is the second line.")
display_doc(document)
remove_line(document, 1)
display_doc(document)

# %% [markdown]
# ---

# %% [markdown]
# ### Python practical: lists
#
# ## 🚶‍♂️ Question 1 – Simple Step Counter
#
# Using the starter code in **q1.py**, create a program with a single function:
#
# * `totalSteps(stepsList)`
#
#   * Takes a list of daily step counts
#
#   * Uses a **while loop** to add them up
#
#   * Returns the total
#
# Your main program should create a list of step counts and print the total.
#
# ***
#
# ## 🍽️ Question 2 – Menu Ordering System
#
# Using the starter code in **q2.py**, write a program that:
#
# * Stores a list of valid menu items
#
# * Asks the user to choose an item
#
# * Validates the choice using a loop
#
# * Allows the user to add multiple valid items to their order
#
# * Stores the final order in a list and displays it
#
# Functions required:
#
# * `getValidItem(menu)`
#
# * `takeOrder(menu)`
#
# ***
#
# ## 🎵 Question 3 – Music Playlist Manager
#
# Build a playlist program in **q3.py** with these features:
#
# * `addSong(playlist, song)` → adds a song only if it isn’t already in the list
#
# * `removeSong(playlist, song)` → removes a song if it exists
#
# * `moveSong(playlist, oldIndex, newIndex)` → moves the song at oldIndex to newIndex, swapping it with the one that is there, which moves to oldIndex. (Use a temporary variable to help with the swap!
#
# * `showPlaylist(playlist)` → prints the playlist

# %%
# q1.py
'''
Return the total number of steps in the list
by adding each value using a while loop.
'''
def totalSteps(stepsList):
    # TODO: delete 'pass' and write code here
    pass

# MAIN PROGRAM
steps = []
# TODO: add some step values to the list
# TODO: print the total using the function

# %%
# q2.py
'''
Repeatedly ask the user to choose a menu item.
Only accept items that appear in the menu list.
Allow the user to add multiple valid items to an order
and return the completed order list.
Hint: takeOrder() needs a while loop that calls getValidItem() 
repeatedly and asking if more items are needed, if not it should end.
'''

def getValidItem(menu):
    # TODO: display menu, ask for input and validate using while loop
    pass

def takeOrder(menu):
    # TODO: allow multiple valid items to be added to an order list
    pass

# MAIN PROGRAM
menu = ["Pizza", "Pasta", "Salad", "Soup"]
order = []

# TODO: call takeOrder and display the final order

# %%
# q3.py
'''
Write a playlist program with four functions
addSong(playlist, song) → adds a song only if it isn't already in the list
removeSong(playlist, song) → removes a song if it exists
moveSong(playlist, oldIndex, newIndex) → moves a song to a new position
showPlaylist(playlist) → prints the playlist
'''

def addSong(playlist, song):
    # TODO: add only if not already in the list
    pass

def removeSong(playlist, song):
    # TODO: remove only if it exists
    pass

def moveSong(playlist, oldIndex, newIndex):
    # TODO: move a song to a new position
    pass

def showPlaylist(playlist):
    # TODO: print the playlist
    pass

# MAIN PROGRAM
playlist = []

# TODO: test your functions here

# %% [markdown]
# ---

# %% [markdown]
# ### Solutions to Python practical: lists
#
# Here are suggested solutions for the practical activities on the previous page. You can run and test the solutions in the attached files.
#
# ## 🚶‍♂️ Question 1 – Simple Step Counter
#
# ```python
# '''
# Return the total number of steps in the list
# by adding each value using a while loop.
# '''
# def totalSteps(stepsList):
#     total = 0
#     index = 0
#
#     while index < len(stepsList):
#         total += stepsList[index]
#         index += 1
#
#     return total
#
# # main program
# steps = [4500, 6200, 7000, 8000]
# print("Total steps:", totalSteps(steps))
# ```
#
# ***
#
# ## 🍽️ Question 2 – Menu Ordering System
#
# ```python
# '''
# Repeatedly ask the user to choose a menu item.
# Only accept items that appear in the menu list.
# Allow the user to add multiple valid items to an order
# and return the completed order list.
# '''
# def getValidItem(menu):
#     item = input("Choose an item: ")
#     while item not in menu:
#         item = input("Not on the menu. Choose an item: ")
#     return item
#
# def takeOrder(menu):
#     order = []
#     addMore = "yes"
#
#     while addMore == "yes":
#         item = getValidItem(menu)
#         order.append(item)
#         addMore = input("Add another item? (yes/no): ")
#
#     return order
#
# # main program
# menu = ["Pizza", "Pasta", "Salad", "Soup"]
# finalOrder = takeOrder(menu)
# print("Your order:", finalOrder)
# ```
#
# ***
#
# ## 🎵 Question 3 – Music Playlist Manager
#
# ```python
# '''
# Manage a playlist by adding unique songs,
# removing songs that exist, moving songs to new positions,
# and displaying the playlist.
# '''
# def addSong(playlist, song):
#     if song not in playlist:
#         playlist.append(song)
#     else:
#         print("Song already in playlist.")
#
# def removeSong(playlist, song):
#     if song in playlist:
#         playlist.remove(song)
#     else:
#         print("Song not found.")
#
# def moveSong(playlist, oldIndex, newIndex):
#     if 0 <= oldIndex < len(playlist) and 0 <= newIndex < len(playlist):
#         temp = playlist[newIndex]
#         playlist[newIndex] = playlist[oldIndex]
#         playlist[oldIndex] = temp
#     else:
#         print("Invalid index(es).")
#
# def showPlaylist(playlist):
#     print("Playlist:", playlist)
#
# # main program
# playlist = []
# addSong(playlist, "Song A")
# addSong(playlist, "Song B")
# addSong(playlist, "Song C")
# moveSong(playlist, 0, 2)
# removeSong(playlist, "Song B")
# showPlaylist(playlist)
# ```

# %%
# q1_solution.py
'''
Return the total number of steps in the list
by adding each value using a while loop.
'''
def totalSteps(stepsList):
    total = 0
    index = 0

    while index < len(stepsList):
        total += stepsList[index]
        index += 1

    return total

# main program
steps = [4500, 6200, 7000, 8000]
print("Total steps:", totalSteps(steps))

# %%
# q2_solution.py
'''
Repeatedly ask the user to choose a menu item.
Only accept items that appear in the menu list.
Allow the user to add multiple valid items to an order
and return the completed order list.
'''
def getValidItem(menu):
    item = input("Choose an item: ")
    while item not in menu:
        item = input("Not on the menu. Choose an item: ")
    return item

def takeOrder(menu):
    order = []
    addMore = "yes"

    while addMore == "yes":
        item = getValidItem(menu)
        order.append(item)
        addMore = input("Add another item? (yes/no): ")

    return order

# main program
menu = ["Pizza", "Pasta", "Salad", "Soup"]
finalOrder = takeOrder(menu)
print("Your order:", finalOrder)

# %%
# q3_solution.py
'''
Manage a playlist by adding unique songs,
removing songs that exist, moving songs to new positions,
and displaying the playlist.
'''
def addSong(playlist, song):
    if song not in playlist:
        playlist.append(song)
    else:
        print("Song already in playlist.")

def removeSong(playlist, song):
    if song in playlist:
        playlist.remove(song)
    else:
        print("Song not found.")

def moveSong(playlist, oldIndex, newIndex):
    if 0 <= oldIndex < len(playlist) and 0 <= newIndex < len(playlist):
        temp = playlist[newIndex]
        playlist[newIndex] = playlist[oldIndex]
        playlist[oldIndex] = temp
    else:
        print("Invalid index.")

def showPlaylist(playlist):
    print("Playlist:", playlist)

# main program
playlist = []
addSong(playlist, "Song A")
addSong(playlist, "Song B")
addSong(playlist, "Song C")
moveSong(playlist, 0, 2)
removeSong(playlist, "Song B")
showPlaylist(playlist)

# %% [markdown]
# ---
