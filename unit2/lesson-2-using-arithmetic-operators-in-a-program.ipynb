# %% [markdown]
# # Lesson 2 - Using Arithmetic Operators in a Program
#
# This lesson consolidates the content in lesson 1 - checking your knowledge and understanding - then guides you through using arithmetic operators in Python.
#
# **Learning objectives:**
# * Understand and use basic arithmetic operators in a high-level language (e.g., Python).
# * Apply arithmetic operations in programming problems.
# * Identify syntax errors and logical errors in arithmetic expressions.
#
# ---

# %% [markdown]
# ### Knowledge Check
#
# ### Retrieval Practice Questions
#
# 1. **What is the result of** **`7 + 3 * 2`** **in Python?**
#
#    * Consider the order of operations (PEMDAS/BODMAS) when evaluating this expression.
#
# 2. **Write a Python expression to divide 45 by 2 and round down to the nearest integer.**
#
#    * Use a single arithmetic operator, and no functions, ensuring the result is an integer.
#
# 3. **What does** **`2 ** 3`** **evaluate to?**
#
#    * Recall what the `**` operator does in Python.
#
# 4. **Which operator would you use to find the remainder of 10 divided by 3?**
#
#    * Identify the operator that provides the remainder of a division operation.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp0_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> What is the result of 7 + 3 * 2 in Python?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_1" value="13"
                 onchange="_qchecku1l1_lp0_1(this.value)"> 13
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_1" value="20"
                 onchange="_qchecku1l1_lp0_1(this.value)"> 20
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_1" value="16"
                 onchange="_qchecku1l1_lp0_1(this.value)"> 16
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_1" value="12"
                 onchange="_qchecku1l1_lp0_1(this.value)"> 12
        </label>
  <div id="qu1l1_lp0_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp0_1_correct = "13";
  var _qu1l1_lp0_1_explanations = {"13": "The multiplication is performed first, so 3 * 2 = 6, then 7 + 6 = 13.", "20": "Wrong because this adds 7 and 3 first, ignoring the order of operations.", "16": "Wrong, did you calculate 3 ** 2 (3 squared) instead of 3 * 2 (3 × 2)?", "12": "Wrong, did you calculate 7 + 3 + 2?"};
  function _qchecku1l1_lp0_1(val) {
    var fb = document.getElementById("qu1l1_lp0_1_fb");
    var expl = _qu1l1_lp0_1_explanations[val] || "";
    if (val === _qu1l1_lp0_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp0_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> Write a Python expression to divide 45 by 2 and round down to the nearest integer. Use a single arithmetic operator, and no functions to achieve the result.</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_2" value="45 // 2"
                 onchange="_qchecku1l1_lp0_2(this.value)"> 45 // 2
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_2" value="45 / 2"
                 onchange="_qchecku1l1_lp0_2(this.value)"> 45 / 2
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_2" value="int(45 / 2)"
                 onchange="_qchecku1l1_lp0_2(this.value)"> int(45 / 2)
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_2" value="round(45 / 2)"
                 onchange="_qchecku1l1_lp0_2(this.value)"> round(45 / 2)
        </label>
  <div id="qu1l1_lp0_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp0_2_correct = "45 // 2";
  var _qu1l1_lp0_2_explanations = {"45 // 2": "The '//' operator performs floor division, rounding down to the nearest integer.", "45 / 2": "The '/' operator performs true division, resulting in a float.", "int(45 / 2)": "This converts the result to an integer but uses a function, not a single arithmetic operator.", "round(45 / 2)": "The 'round' function rounds to the nearest integer, not necessarily down, and the question required no use of functions."};
  function _qchecku1l1_lp0_2(val) {
    var fb = document.getElementById("qu1l1_lp0_2_fb");
    var expl = _qu1l1_lp0_2_explanations[val] || "";
    if (val === _qu1l1_lp0_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp0_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> What does 2 ** 3 evaluate to?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_3" value="8"
                 onchange="_qchecku1l1_lp0_3(this.value)"> 8
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_3" value="6"
                 onchange="_qchecku1l1_lp0_3(this.value)"> 6
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_3" value="9"
                 onchange="_qchecku1l1_lp0_3(this.value)"> 9
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_3" value="5"
                 onchange="_qchecku1l1_lp0_3(this.value)"> 5
        </label>
  <div id="qu1l1_lp0_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp0_3_correct = "8";
  var _qu1l1_lp0_3_explanations = {"8": "Correct because 2 ** 3 means 2 raised to the power of 3 (2 cubed).", "6": "Wrong because it's the result of 2 * 3 (2 × 3) not exponentiation.", "9": "Wrong because 2 ** 3 is not the same as 3 squared.", "5": "Incorrect because this is the result of 2 + 3 not 2 ** 3."};
  function _qchecku1l1_lp0_3(val) {
    var fb = document.getElementById("qu1l1_lp0_3_fb");
    var expl = _qu1l1_lp0_3_explanations[val] || "";
    if (val === _qu1l1_lp0_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp0_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> Which operator would you use to find the remainder of 10 divided by 3?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_4" value="%"
                 onchange="_qchecku1l1_lp0_4(this.value)"> %
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_4" value="//"
                 onchange="_qchecku1l1_lp0_4(this.value)"> //
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_4" value="/"
                 onchange="_qchecku1l1_lp0_4(this.value)"> /
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp0_4" value="**"
                 onchange="_qchecku1l1_lp0_4(this.value)"> **
        </label>
  <div id="qu1l1_lp0_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp0_4_correct = "%";
  var _qu1l1_lp0_4_explanations = {"%": "The % operator (modulus) is used to find the remainder like this: 10 % 3.", "//": "This is integer or 'floor' division, not remainder.", "/": "The / operator is used for division, not for finding the remainder.", "**": "This is exponentiation, not finding the remainder."};
  function _qchecku1l1_lp0_4(val) {
    var fb = document.getElementById("qu1l1_lp0_4_fb");
    var expl = _qu1l1_lp0_4_explanations[val] || "";
    if (val === _qu1l1_lp0_4_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Recap - key terms
#
# Review this table of key terms and symbols, then take the quiz on the next page.
#
# | Term or Symbol | Name              | Purpose                                                  |
# |----------------|-------------------|----------------------------------------------------------|
# | `+`            | Addition          | Add both operands                                        |
# | `-`            | Subtraction       | Subtract second operand from first                       |
# | `*`            | Multiplication    | Multiply two operands                                    |
# | `/`            | (Real) Division   | Divide and return a real number (float)                 |
# | `//`           | Integer Division  | Divide and return only the integer part                 |
# | `%`            | Modulus           | Find the remainder after integer division               |
# | `**`           | Exponent          | Raise to the power of                                   |
# | Operator       | N/A               | A symbol for an operation such as `+`, `-`, `*`, `/`     |
# | Operand        | N/A               | Terms either side of the operator, e.g. `3` and `4` in `3 + 4` |
# | Integer        | N/A               | A whole number such as `7`, `-1`                         |
# | Float          | N/A               | A number with a decimal part, also called Real, such as `4.0`, `3.14`, `9.999999` |

# %% [markdown]
# ---

# %% [markdown]
# ### Key terms missing words quiz
#
# Complete the sentences below, on the key terms in this topic.

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp2_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> Real division, using the / symbol, divides two numbers and returns a _____ number, also called a float</p>
  <input id="qu1l1_lp2_1_in" type="text" placeholder="Type your answer..."
         style="padding:4px 8px;width:50%;border:1px solid #ccc;border-radius:4px">
  <button onclick="_qchecku1l1_lp2_1()"
          style="margin-left:8px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu1l1_lp2_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp2_1_correct = "real";
  var _qu1l1_lp2_1_explanation = null;
  function _qchecku1l1_lp2_1() {
    var answer = document.getElementById("qu1l1_lp2_1_in").value.trim().toLowerCase();
    var fb = document.getElementById("qu1l1_lp2_1_fb");
    if (answer === "") {
      fb.innerHTML = "<span style='color:grey'>&#128161; Answer: <b>" + _qu1l1_lp2_1_correct + "</b> &mdash; " + _qu1l1_lp2_1_explanation + "</span>";
    } else if (answer === _qu1l1_lp2_1_correct.toLowerCase()) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + _qu1l1_lp2_1_explanation + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite &mdash; try again, or clear your answer and click Check to reveal.</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp2_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> The symbol // represents ________ division, also called 'floor' division, because it always returns a whole number.</p>
  <input id="qu1l1_lp2_2_in" type="text" placeholder="Type your answer..."
         style="padding:4px 8px;width:50%;border:1px solid #ccc;border-radius:4px">
  <button onclick="_qchecku1l1_lp2_2()"
          style="margin-left:8px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu1l1_lp2_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp2_2_correct = "integer";
  var _qu1l1_lp2_2_explanation = null;
  function _qchecku1l1_lp2_2() {
    var answer = document.getElementById("qu1l1_lp2_2_in").value.trim().toLowerCase();
    var fb = document.getElementById("qu1l1_lp2_2_fb");
    if (answer === "") {
      fb.innerHTML = "<span style='color:grey'>&#128161; Answer: <b>" + _qu1l1_lp2_2_correct + "</b> &mdash; " + _qu1l1_lp2_2_explanation + "</span>";
    } else if (answer === _qu1l1_lp2_2_correct.toLowerCase()) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + _qu1l1_lp2_2_explanation + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite &mdash; try again, or clear your answer and click Check to reveal.</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp2_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> The Python operator %, with pseudocode keyword MOD, finds the ________ after division.</p>
  <input id="qu1l1_lp2_3_in" type="text" placeholder="Type your answer..."
         style="padding:4px 8px;width:50%;border:1px solid #ccc;border-radius:4px">
  <button onclick="_qchecku1l1_lp2_3()"
          style="margin-left:8px;padding:4px 14px;cursor:pointer">Check</button>
  <div id="qu1l1_lp2_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp2_3_correct = "remainder";
  var _qu1l1_lp2_3_explanation = null;
  function _qchecku1l1_lp2_3() {
    var answer = document.getElementById("qu1l1_lp2_3_in").value.trim().toLowerCase();
    var fb = document.getElementById("qu1l1_lp2_3_fb");
    if (answer === "") {
      fb.innerHTML = "<span style='color:grey'>&#128161; Answer: <b>" + _qu1l1_lp2_3_correct + "</b> &mdash; " + _qu1l1_lp2_3_explanation + "</span>";
    } else if (answer === _qu1l1_lp2_3_correct.toLowerCase()) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + _qu1l1_lp2_3_explanation + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite &mdash; try again, or clear your answer and click Check to reveal.</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp2_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> The symbol ** is used to raise a number to the power of another number, its proper name is the ________ symbol.</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp2_4" value="exponent"
                 onchange="_qchecku1l1_lp2_4(this.value)"> exponent
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp2_4" value="modulus"
                 onchange="_qchecku1l1_lp2_4(this.value)"> modulus
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp2_4" value="logarithm"
                 onchange="_qchecku1l1_lp2_4(this.value)"> logarithm
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp2_4" value="root"
                 onchange="_qchecku1l1_lp2_4(this.value)"> root
        </label>
  <div id="qu1l1_lp2_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp2_4_correct = "exponent";
  var _qu1l1_lp2_4_explanations = {"exponent": "Yes, the operator is \"exponent\", the process is exponentiation.", "modulus": "No, this is the remainder", "logarithm": "No this is the opposite operation to what we need!", "root": "No this is not the general operation we are looking for (although roots are fractional powers!)"};
  function _qchecku1l1_lp2_4(val) {
    var fb = document.getElementById("qu1l1_lp2_4_fb");
    var expl = _qu1l1_lp2_4_explanations[val] || "";
    if (val === _qu1l1_lp2_4_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp2_5" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q5.</b> The terms either side of the operator, e.g. 3 and 4 in 3 + 4 are called ____________.</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp2_5" value="operands"
                 onchange="_qchecku1l1_lp2_5(this.value)"> operands
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp2_5" value="operators"
                 onchange="_qchecku1l1_lp2_5(this.value)"> operators
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp2_5" value="variables"
                 onchange="_qchecku1l1_lp2_5(this.value)"> variables
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp2_5" value="constants"
                 onchange="_qchecku1l1_lp2_5(this.value)"> constants
        </label>
  <div id="qu1l1_lp2_5_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp2_5_correct = "operands";
  var _qu1l1_lp2_5_explanations = {"operands": "Correct, an operator takes one or more operands.", "operators": "Wrong, this is the symbol in the middle.", "variables": "Wrong, the terms in an arithmetic operation may not always be variables, they can be constants or other expressions.", "constants": "Wrong, the terms in an arithmetic operation may not always be constants, they can be variables or other expressions."};
  function _qchecku1l1_lp2_5(val) {
    var fb = document.getElementById("qu1l1_lp2_5_fb");
    var expl = _qu1l1_lp2_5_explanations[val] || "";
    if (val === _qu1l1_lp2_5_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Operators quick quiz
#
# Now take this quiz to check your recall of operators. All the answers can be found here:
#
# | Addition | Subtraction | Multiplication | Division | Modulus |
# |:--------:|:-----------:|:--------------:|:--------:|:-------:|
# |   `+`    |     `-`     |      `*`       |   `/`    |   `%`   |

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp3_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> The _____ operator is used to calculate the total of two values.</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_1" value="\+"
                 onchange="_qchecku1l1_lp3_1(this.value)"> \+
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_1" value="\-"
                 onchange="_qchecku1l1_lp3_1(this.value)"> \-
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_1" value="\*"
                 onchange="_qchecku1l1_lp3_1(this.value)"> \*
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_1" value="/"
                 onchange="_qchecku1l1_lp3_1(this.value)"> /
        </label>
  <div id="qu1l1_lp3_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp3_1_correct = "\\+";
  var _qu1l1_lp3_1_explanations = {"\\+": "The '+' operator is used for addition, which calculates the total of two values.", "\\-": "The '-' operator is used for subtraction, not addition.", "\\*": "The '*' operator is used for multiplication, not addition.", "/": "The '/' operator is used for division, not addition."};
  function _qchecku1l1_lp3_1(val) {
    var fb = document.getElementById("qu1l1_lp3_1_fb");
    var expl = _qu1l1_lp3_1_explanations[val] || "";
    if (val === _qu1l1_lp3_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp3_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> The * symbol is used for _____ in Python.</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_2" value="multiplication"
                 onchange="_qchecku1l1_lp3_2(this.value)"> multiplication
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_2" value="addition"
                 onchange="_qchecku1l1_lp3_2(this.value)"> addition
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_2" value="division"
                 onchange="_qchecku1l1_lp3_2(this.value)"> division
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_2" value="subtraction"
                 onchange="_qchecku1l1_lp3_2(this.value)"> subtraction
        </label>
  <div id="qu1l1_lp3_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp3_2_correct = "multiplication";
  var _qu1l1_lp3_2_explanations = {"multiplication": "The * symbol is used for multiplication in Python.", "addition": "The + symbol is used for addition in Python.", "division": "The / symbol is used for division in Python.", "subtraction": "The - symbol is used for subtraction in Python."};
  function _qchecku1l1_lp3_2(val) {
    var fb = document.getElementById("qu1l1_lp3_2_fb");
    var expl = _qu1l1_lp3_2_explanations[val] || "";
    if (val === _qu1l1_lp3_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp3_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> The / operator performs _____ and returns the quotient.</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_3" value="division"
                 onchange="_qchecku1l1_lp3_3(this.value)"> division
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_3" value="multiplication"
                 onchange="_qchecku1l1_lp3_3(this.value)"> multiplication
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_3" value="addition"
                 onchange="_qchecku1l1_lp3_3(this.value)"> addition
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_3" value="subtraction"
                 onchange="_qchecku1l1_lp3_3(this.value)"> subtraction
        </label>
  <div id="qu1l1_lp3_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp3_3_correct = "division";
  var _qu1l1_lp3_3_explanations = {"division": "The / operator is used for division and returns the quotient (the result of dividing one number by another).", "multiplication": "The * operator is used for multiplication, not division.", "addition": "The + operator is used for addition, not division.", "subtraction": "The - operator is used for subtraction, not division."};
  function _qchecku1l1_lp3_3(val) {
    var fb = document.getElementById("qu1l1_lp3_3_fb");
    var expl = _qu1l1_lp3_3_explanations[val] || "";
    if (val === _qu1l1_lp3_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp3_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> The _____ operation finds the remainder after division, also called ______.</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_4" value="%, modulus"
                 onchange="_qchecku1l1_lp3_4(this.value)"> %, modulus
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_4" value="+, addition"
                 onchange="_qchecku1l1_lp3_4(this.value)"> +, addition
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp3_4" value="/, division"
                 onchange="_qchecku1l1_lp3_4(this.value)"> /, division
        </label>
  <div id="qu1l1_lp3_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp3_4_correct = "%, modulus";
  var _qu1l1_lp3_4_explanations = {"%, modulus": "The modulus operation, represented by %, finds the remainder after division and is also known as modulo.", "+, addition": "Addition is used to calculate the total of two values, not the remainder after division.", "/, division": "Division calculates the quotient, not the remainder after division."};
  function _qchecku1l1_lp3_4(val) {
    var fb = document.getElementById("qu1l1_lp3_4_fb");
    var expl = _qu1l1_lp3_4_explanations[val] || "";
    if (val === _qu1l1_lp3_4_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Python debugging exercise 1
#
# Open the Python file and complete these tasks
#
# 1. Find the line where the error is
# 2. Decide whether it is a Syntax or Logical error
# 3. Predict the outcome of attempting to run the code (will it just not run, will it run and stop, what error will be reported?)
# 4. Fix the code and test it.
#
# Then answer the questions below.

# %%
# b1_debug.py
#add two numbers
num1 = 10
num2 = 4
result = num1 + num2 - 
print("Result is:", result)

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp4_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> On which line is the error?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_1" value="4"
                 onchange="_qchecku1l1_lp4_1(this.value)"> 4
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_1" value="3"
                 onchange="_qchecku1l1_lp4_1(this.value)"> 3
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_1" value="2"
                 onchange="_qchecku1l1_lp4_1(this.value)"> 2
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_1" value="5"
                 onchange="_qchecku1l1_lp4_1(this.value)"> 5
        </label>
  <div id="qu1l1_lp4_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp4_1_correct = "4";
  var _qu1l1_lp4_1_explanations = {"4": "Correct, there is a stray minus sign causing Python to expect another value at the end.", "3": "Wrong, this line is syntactically correct", "2": "Wrong, this line is syntactically correct", "5": "Wrong, this line is syntactically correct"};
  function _qchecku1l1_lp4_1(val) {
    var fb = document.getElementById("qu1l1_lp4_1_fb");
    var expl = _qu1l1_lp4_1_explanations[val] || "";
    if (val === _qu1l1_lp4_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp4_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> Is this a logical or syntax error?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_2" value="Logical"
                 onchange="_qchecku1l1_lp4_2(this.value)"> Logical
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_2" value="Syntax"
                 onchange="_qchecku1l1_lp4_2(this.value)"> Syntax
        </label>
  <div id="qu1l1_lp4_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp4_2_correct = "Syntax";
  var _qu1l1_lp4_2_explanations = {"Logical": "Wrong, the logic is correct (if the error is dealt with)", "Syntax": "Correct, the program breaks the rules of Python which is a syntax error."};
  function _qchecku1l1_lp4_2(val) {
    var fb = document.getElementById("qu1l1_lp4_2_fb");
    var expl = _qu1l1_lp4_2_explanations[val] || "";
    if (val === _qu1l1_lp4_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp4_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> Predict: what will happen if we try to run the code?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_3" value="The program won't start"
                 onchange="_qchecku1l1_lp4_3(this.value)"> The program won't start
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_3" value="The program will start and fail at line 3"
                 onchange="_qchecku1l1_lp4_3(this.value)"> The program will start and fail at line 3
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_3" value="The program will complete but with unexpected results"
                 onchange="_qchecku1l1_lp4_3(this.value)"> The program will complete but with unexpected results
        </label>
  <div id="qu1l1_lp4_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp4_3_correct = "The program won't start";
  var _qu1l1_lp4_3_explanations = {"The program won't start": "Correct, a syntax error prevents the program starting", "The program will start and fail at line 3": "Wrong, a syntax error prevents the program running", "The program will complete but with unexpected results": "Wrong, a syntax error prevents the program running"};
  function _qchecku1l1_lp4_3(val) {
    var fb = document.getElementById("qu1l1_lp4_3_fb");
    var expl = _qu1l1_lp4_3_explanations[val] || "";
    if (val === _qu1l1_lp4_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp4_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> How can we fix this program without changing the programmer's intention?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_4" value="Remove the stray minus sign"
                 onchange="_qchecku1l1_lp4_4(this.value)"> Remove the stray minus sign
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_4" value="Place a constant after the minus sign"
                 onchange="_qchecku1l1_lp4_4(this.value)"> Place a constant after the minus sign
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp4_4" value="Change the minus sign to a plus sign"
                 onchange="_qchecku1l1_lp4_4(this.value)"> Change the minus sign to a plus sign
        </label>
  <div id="qu1l1_lp4_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp4_4_correct = "Remove the stray minus sign";
  var _qu1l1_lp4_4_explanations = {"Remove the stray minus sign": "Correct", "Place a constant after the minus sign": "Wrong, this would fix the syntax error but change the result", "Change the minus sign to a plus sign": "Wrong, this would not resolve the syntax error"};
  function _qchecku1l1_lp4_4(val) {
    var fb = document.getElementById("qu1l1_lp4_4_fb");
    var expl = _qu1l1_lp4_4_explanations[val] || "";
    if (val === _qu1l1_lp4_4_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Python debugging exercise 2
#
# Open the Python file and complete these tasks:
# 1. Spot the error(s) in the code
# 2. Decide whether each is a Syntax or Logical error
# 3. Predict the outcome of attempting to run the code
# 4. Fix the code and test it
# Then answer the questions below.

# %%
# b2_debug.py
# calculate area of a rectangle
length = 7
width = 3
area = length x width
print("Area:", area)

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp5_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> What is the error in this program?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_1" value="The multiplication uses `x` instead of `*`"
                 onchange="_qchecku1l1_lp5_1(this.value)"> The multiplication uses `x` instead of `*`
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_1" value="The variable `area` is undefined"
                 onchange="_qchecku1l1_lp5_1(this.value)"> The variable `area` is undefined
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_1" value="The print statement is missing a closing bracket"
                 onchange="_qchecku1l1_lp5_1(this.value)"> The print statement is missing a closing bracket
        </label>
  <div id="qu1l1_lp5_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp5_1_correct = "The multiplication uses `x` instead of `*`";
  var _qu1l1_lp5_1_explanations = {"The multiplication uses `x` instead of `*`": "Correct, Python expects `*` for multiplication, not `x`", "The variable `area` is undefined": "Wrong, `area` is defined, but the expression is invalid", "The print statement is missing a closing bracket": "Wrong, the print syntax is correct"};
  function _qchecku1l1_lp5_1(val) {
    var fb = document.getElementById("qu1l1_lp5_1_fb");
    var expl = _qu1l1_lp5_1_explanations[val] || "";
    if (val === _qu1l1_lp5_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp5_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> What type of error is this?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_2" value="Syntax Error"
                 onchange="_qchecku1l1_lp5_2(this.value)"> Syntax Error
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_2" value="Logical Error"
                 onchange="_qchecku1l1_lp5_2(this.value)"> Logical Error
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_2" value="Runtime Error"
                 onchange="_qchecku1l1_lp5_2(this.value)"> Runtime Error
        </label>
  <div id="qu1l1_lp5_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp5_2_correct = "Syntax Error";
  var _qu1l1_lp5_2_explanations = {"Syntax Error": "Correct, Python reads `x` as a variable and throws a syntax error", "Logical Error": "Wrong, the program won't run at all", "Runtime Error": "Wrong, the error is detected before execution"};
  function _qchecku1l1_lp5_2(val) {
    var fb = document.getElementById("qu1l1_lp5_2_fb");
    var expl = _qu1l1_lp5_2_explanations[val] || "";
    if (val === _qu1l1_lp5_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp5_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> What will happen when you try to run the original code?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_3" value="The program won't start"
                 onchange="_qchecku1l1_lp5_3(this.value)"> The program won't start
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_3" value="It prints `Area: 21`"
                 onchange="_qchecku1l1_lp5_3(this.value)"> It prints `Area: 21`
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_3" value="It prints `Area: x`"
                 onchange="_qchecku1l1_lp5_3(this.value)"> It prints `Area: x`
        </label>
  <div id="qu1l1_lp5_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp5_3_correct = "The program won't start";
  var _qu1l1_lp5_3_explanations = {"The program won't start": "Correct, Python throws a syntax error and halts", "It prints `Area: 21`": "Wrong, the code doesn't reach the print statement", "It prints `Area: x`": "Wrong, `x` is not defined and causes a syntax error"};
  function _qchecku1l1_lp5_3(val) {
    var fb = document.getElementById("qu1l1_lp5_3_fb");
    var expl = _qu1l1_lp5_3_explanations[val] || "";
    if (val === _qu1l1_lp5_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp5_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> How should the code be fixed?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_4" value="Replace `x` with `*`"
                 onchange="_qchecku1l1_lp5_4(this.value)"> Replace `x` with `*`
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_4" value="Add quotation marks around `x`"
                 onchange="_qchecku1l1_lp5_4(this.value)"> Add quotation marks around `x`
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp5_4" value="Change `print` to `print()`"
                 onchange="_qchecku1l1_lp5_4(this.value)"> Change `print` to `print()`
        </label>
  <div id="qu1l1_lp5_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp5_4_correct = "Replace `x` with `*`";
  var _qu1l1_lp5_4_explanations = {"Replace `x` with `*`": "Correct, `*` is the proper multiplication operator in Python", "Add quotation marks around `x`": "Wrong, that would make it a string, not an operator", "Change `print` to `print()`": "Wrong, the print syntax is already correct"};
  function _qchecku1l1_lp5_4(val) {
    var fb = document.getElementById("qu1l1_lp5_4_fb");
    var expl = _qu1l1_lp5_4_explanations[val] || "";
    if (val === _qu1l1_lp5_4_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Python debugging exercise 3
#
# Open the Python file and complete these tasks:
# 1. Spot the error(s) in the code
# 2. Decide whether each is a Syntax, Logical, or Runtime error
# 3. Predict the outcome of attempting to run the code
# 4. Fix the code and test it
# Then answer the questions below.

# %%
# b3_debug.py
# find average of two numbers 
num1 = input("Enter first number: ")
num2 = input("Enter second number: ")
total = num1 + num1
average = total // 2
print("Average is: " + average)

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp6_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> What is the first issue in this program?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_1" value="Inputs are not cast to numbers"
                 onchange="_qchecku1l1_lp6_1(this.value)"> Inputs are not cast to numbers
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_1" value="The input prompts are missing"
                 onchange="_qchecku1l1_lp6_1(this.value)"> The input prompts are missing
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_1" value="The variables are undefined"
                 onchange="_qchecku1l1_lp6_1(this.value)"> The variables are undefined
        </label>
  <div id="qu1l1_lp6_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp6_1_correct = "Inputs are not cast to numbers";
  var _qu1l1_lp6_1_explanations = {"Inputs are not cast to numbers": "Correct, input() returns strings, which causes issues later", "The input prompts are missing": "Wrong, the prompts are present", "The variables are undefined": "Wrong, num1 and num2 are defined"};
  function _qchecku1l1_lp6_1(val) {
    var fb = document.getElementById("qu1l1_lp6_1_fb");
    var expl = _qu1l1_lp6_1_explanations[val] || "";
    if (val === _qu1l1_lp6_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp6_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> What type of error does this cause?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_2" value="Logical and Runtime Error"
                 onchange="_qchecku1l1_lp6_2(this.value)"> Logical and Runtime Error
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_2" value="Syntax Error"
                 onchange="_qchecku1l1_lp6_2(this.value)"> Syntax Error
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_2" value="No error"
                 onchange="_qchecku1l1_lp6_2(this.value)"> No error
        </label>
  <div id="qu1l1_lp6_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp6_2_correct = "Logical and Runtime Error";
  var _qu1l1_lp6_2_explanations = {"Logical and Runtime Error": "Correct, the logic is flawed and it crashes when adding strings", "Syntax Error": "Wrong, the syntax is valid", "No error": "Wrong, the program will fail at runtime"};
  function _qchecku1l1_lp6_2(val) {
    var fb = document.getElementById("qu1l1_lp6_2_fb");
    var expl = _qu1l1_lp6_2_explanations[val] || "";
    if (val === _qu1l1_lp6_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp6_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> What is wrong with the calculation of total on line 4?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_3" value="It adds num1 to itself instead of num2"
                 onchange="_qchecku1l1_lp6_3(this.value)"> It adds num1 to itself instead of num2
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_3" value="It uses subtraction instead of addition"
                 onchange="_qchecku1l1_lp6_3(this.value)"> It uses subtraction instead of addition
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_3" value="It multiplies instead of adds"
                 onchange="_qchecku1l1_lp6_3(this.value)"> It multiplies instead of adds
        </label>
  <div id="qu1l1_lp6_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp6_3_correct = "It adds num1 to itself instead of num2";
  var _qu1l1_lp6_3_explanations = {"It adds num1 to itself instead of num2": "Correct, this is a logical error", "It uses subtraction instead of addition": "Wrong, the operator is +", "It multiplies instead of adds": "Wrong, no multiplication is used"};
  function _qchecku1l1_lp6_3(val) {
    var fb = document.getElementById("qu1l1_lp6_3_fb");
    var expl = _qu1l1_lp6_3_explanations[val] || "";
    if (val === _qu1l1_lp6_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp6_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> What is wrong with the average calculation?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_4" value="Integer division // is used instead of /"
                 onchange="_qchecku1l1_lp6_4(this.value)"> Integer division // is used instead of /
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_4" value="The average is calculated before the total"
                 onchange="_qchecku1l1_lp6_4(this.value)"> The average is calculated before the total
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_4" value="The average is printed before being calculated"
                 onchange="_qchecku1l1_lp6_4(this.value)"> The average is printed before being calculated
        </label>
  <div id="qu1l1_lp6_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp6_4_correct = "Integer division // is used instead of /";
  var _qu1l1_lp6_4_explanations = {"Integer division // is used instead of /": "Correct, // truncates the result", "The average is calculated before the total": "Wrong, the order is fine", "The average is printed before being calculated": "Wrong, the print correctly comes after the calculation"};
  function _qchecku1l1_lp6_4(val) {
    var fb = document.getElementById("qu1l1_lp6_4_fb");
    var expl = _qu1l1_lp6_4_explanations[val] || "";
    if (val === _qu1l1_lp6_4_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp6_5" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q5.</b> What is wrong with the final print statement?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_5" value="It tries to concatenate a string and a number"
                 onchange="_qchecku1l1_lp6_5(this.value)"> It tries to concatenate a string and a number
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_5" value="It uses a comma instead of a plus"
                 onchange="_qchecku1l1_lp6_5(this.value)"> It uses a comma instead of a plus
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp6_5" value="It prints the wrong variable"
                 onchange="_qchecku1l1_lp6_5(this.value)"> It prints the wrong variable
        </label>
  <div id="qu1l1_lp6_5_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp6_5_correct = "It tries to concatenate a string and a number";
  var _qu1l1_lp6_5_explanations = {"It tries to concatenate a string and a number": "Correct, Python can't join a string and an integer with +", "It uses a comma instead of a plus": "Wrong, using a comma would actually fix the issue", "It prints the wrong variable": "Wrong, the correct variable is printed"};
  function _qchecku1l1_lp6_5(val) {
    var fb = document.getElementById("qu1l1_lp6_5_fb");
    var expl = _qu1l1_lp6_5_explanations[val] || "";
    if (val === _qu1l1_lp6_5_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Python practical exercises 3
#
# This program attempts to convert temperature values in Fahrenheit to Celsius, but it contains errors The correct process for this is "subtract 32, then multiply by five-ninths".
#
# Open the Python file and complete these tasks:
#
# ## PRIMM Activities
#
# 1. 🤔 **Predict:** what the code will do.
# 2. ▶️ **Run** and check your prediction.
# 3. 🔍**Investigate:** spot the error(s) in the code and decide whether each is a Syntax, Logical, or Runtime error
# 4. ✏️**Modify:** Fix the code and test it, then answer the questions below.
# 5. 🛠️ **Make:** write a new function **`cToF`** to convert Celsius temperatures to Fahrenheit.

# %%
# b4_debug.py
# convert temperature from f to c
def fToC(fahrenheit):
    celsius = fahrenheit - 32 ** 5 / 9
    return celsius

#main program
print(fToC(70))

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp7_1" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q1.</b> What is the first error in this program?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_1" value="The formula uses ** instead of *"
                 onchange="_qchecku1l1_lp7_1(this.value)"> The formula uses ** instead of *
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_1" value="The formula uses / instead of //"
                 onchange="_qchecku1l1_lp7_1(this.value)"> The formula uses / instead of //
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_1" value="The return statement is missing"
                 onchange="_qchecku1l1_lp7_1(this.value)"> The return statement is missing
        </label>
  <div id="qu1l1_lp7_1_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp7_1_correct = "The formula uses ** instead of *";
  var _qu1l1_lp7_1_explanations = {"The formula uses ** instead of *": "Correct, ** is exponentiation, not multiplication", "The formula uses / instead of //": "Wrong, / is correct for decimal division", "The return statement is missing": "Wrong, the return statement is present"};
  function _qchecku1l1_lp7_1(val) {
    var fb = document.getElementById("qu1l1_lp7_1_fb");
    var expl = _qu1l1_lp7_1_explanations[val] || "";
    if (val === _qu1l1_lp7_1_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp7_2" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q2.</b> What is the second error in this program?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_2" value="Missing brackets around (fahrenheit - 32)"
                 onchange="_qchecku1l1_lp7_2(this.value)"> Missing brackets around (fahrenheit - 32)
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_2" value="The function name is invalid"
                 onchange="_qchecku1l1_lp7_2(this.value)"> The function name is invalid
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_2" value="The subtraction uses the wrong operator"
                 onchange="_qchecku1l1_lp7_2(this.value)"> The subtraction uses the wrong operator
        </label>
  <div id="qu1l1_lp7_2_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp7_2_correct = "Missing brackets around (fahrenheit - 32)";
  var _qu1l1_lp7_2_explanations = {"Missing brackets around (fahrenheit - 32)": "Correct, without brackets Python evaluates operations in the wrong order", "The function name is invalid": "Wrong, the function name is fine", "The subtraction uses the wrong operator": "Wrong, the minus sign is correct"};
  function _qchecku1l1_lp7_2(val) {
    var fb = document.getElementById("qu1l1_lp7_2_fb");
    var expl = _qu1l1_lp7_2_explanations[val] || "";
    if (val === _qu1l1_lp7_2_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp7_3" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q3.</b> What type of error does this cause?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_3" value="Logical Error"
                 onchange="_qchecku1l1_lp7_3(this.value)"> Logical Error
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_3" value="Syntax Error"
                 onchange="_qchecku1l1_lp7_3(this.value)"> Syntax Error
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_3" value="Runtime Error"
                 onchange="_qchecku1l1_lp7_3(this.value)"> Runtime Error
        </label>
  <div id="qu1l1_lp7_3_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp7_3_correct = "Logical Error";
  var _qu1l1_lp7_3_explanations = {"Logical Error": "Correct, the program runs but gives incorrect results", "Syntax Error": "Wrong, the syntax is valid", "Runtime Error": "Wrong, the program does not crash"};
  function _qchecku1l1_lp7_3(val) {
    var fb = document.getElementById("qu1l1_lp7_3_fb");
    var expl = _qu1l1_lp7_3_explanations[val] || "";
    if (val === _qu1l1_lp7_3_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %%
from IPython.display import display, HTML
display(HTML('''
<div id="qu1l1_lp7_4" style="border:1px solid #ddd;border-radius:6px;padding:14px;margin:8px 0;font-family:sans-serif">
  <p><b>Q4.</b> What is the correct formula for converting Fahrenheit to Celsius?</p>
  <label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_4" value="(fahrenheit - 32) * 5 / 9"
                 onchange="_qchecku1l1_lp7_4(this.value)"> (fahrenheit - 32) * 5 / 9
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_4" value="fahrenheit - 32 * 5 / 9"
                 onchange="_qchecku1l1_lp7_4(this.value)"> fahrenheit - 32 * 5 / 9
        </label>
<label style="display:block;margin:4px 0;cursor:pointer">
          <input type="radio" name="qu1l1_lp7_4" value="fahrenheit - (32 * 5 / 9)"
                 onchange="_qchecku1l1_lp7_4(this.value)"> fahrenheit - (32 * 5 / 9)
        </label>
  <div id="qu1l1_lp7_4_fb" style="margin-top:8px;min-height:24px"></div>
</div>
<script>
  var _qu1l1_lp7_4_correct = "(fahrenheit - 32) * 5 / 9";
  var _qu1l1_lp7_4_explanations = {"(fahrenheit - 32) * 5 / 9": "Correct, this applies the correct order of operations", "fahrenheit - 32 * 5 / 9": "Wrong, this multiplies before subtracting", "fahrenheit - (32 * 5 / 9)": "Wrong, this subtracts a constant (roughly 17.8 every time!) instead of scaling the difference"};
  function _qchecku1l1_lp7_4(val) {
    var fb = document.getElementById("qu1l1_lp7_4_fb");
    var expl = _qu1l1_lp7_4_explanations[val] || "";
    if (val === _qu1l1_lp7_4_correct) {
      fb.innerHTML = "<span style='color:green'>&#10003; Correct! " + expl + "</span>";
    } else {
      fb.innerHTML = "<span style='color:crimson'>&#10007; Not quite. " + expl + "</span>";
    }
  }
</script>
'''))

# %% [markdown]
# ---

# %% [markdown]
# ### Common misconceptions 1
#
# ##
#
# | ❌ Misconception                                | 🧪 What Students Might Do                     | ✅ Explanation / Fix                                                                                          |
# | ---------------------------------------------- | --------------------------------------------- | ------------------------------------------------------------------------------------------------------------ |
# | `/ 0`, `// 0`, and `% 0` are valid             | `average = total / countmodulus = number % 0` | Causes `ZeroDivisionError`. Always check that the denominator is not zero before using `/`, `//`, or `%`.    |
# | `x` means multiply                             | `area = length x width`                       | Python treats `x` as a variable, not an operator. Use `*` for multiplication.                                |
# | You can add or concatenate strings and numbers | `print("Score: " + score)`                    | You can't concatenate a string and an integer with `+`. Use `str(score)` or commas: `print("Score:", score)` |

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %% [markdown]
# **Q1.** *(Reflection)*
# Which of these misconceptions have you struggled with? Which have you "seen in the wild"? What can you do to avoid it in the future?
#
# *Write your thoughts in the cell below.*

# %%
# Q1 — your reflection
reflection = """

"""

# %% [markdown]
# ---

# %% [markdown]
# ### Common misconceptions 2
#
# | ❌ Misconception                      | 🧪 What Students Might Do      | ✅ Explanation / Fix                                                                                              |
# | ------------------------------------ | ------------------------------ | ---------------------------------------------------------------------------------------------------------------- |
# | Operators work left to right         | `4 + 2 * 3`Expecting `18`      | Python follows precedence: `2 * 3 = 6`, then `4 + 6 = 10`. Use brackets to override precedence if needed.        |
# | `%` gives a percentage               | `percent = score % total`      | `%` gives the remainder, not a percentage. Use: `percent = score / total * 100`                                  |
# | Multiple `**` evaluate left to right | `2 ** 3 ** 2`Expecting `64`    | Python evaluates exponentiation right to left: `3 ** 2 = 9`, then `2 ** 9 = 512`. Use brackets to control order. |
# | Mixed units                          | `total = hours * 60 + seconds` | Keep units consistent. Convert all values to the same unit (e.g. minutes or seconds) before calculating.         |

# %% [markdown]
# ---
# ### ✏️ Check your understanding

# %% [markdown]
# **Q1.** *(Reflection)*
# Which of these misconceptions have you struggled with? Which have you "seen in the wild"? What can you do to avoid it in the future?
#
# *Write your thoughts in the cell below.*

# %%
# Q1 — your reflection
reflection = """

"""

# %% [markdown]
# ---

# %% [markdown]
# ### Python debugging exercise 4
#
# Our final quick-fire debugging exercise before you fly solo!
#
# This program attempts to input scores repeatedly until the user enters **-1** which should end the loop, and calculate and display the average score. But there are many errors in the code. Can you spot and fix them all?
#
# Open the Python file and complete these tasks:
#
# 1. Spot the error(s) in the code
# 2. Decide whether each is a Syntax, Logical, or Runtime error
# 3. Predict the outcome of attempting to run the code
# 4. Fix the code and test it
#    Then answer the questions below.

# %%
# b5_debug.py
count = 0
total = 0
finished = False
while not finished:
  score = int(input("Enter score, -1 to quit: ")
  total += score
  if score = -1:
    finished = True
print("Average = ", total / count)

# %% [markdown]
# ---

# %% [markdown]
# ### Python practical exercises 4
#
# Using the skeleton code provided, solve these problems:
#
# ### 1. Shopping Bill
#
# Complete the code in **q1.py**. Input the prices of three items.\
# Calculate the total and output it.
#
# ***
#
# ### 2. Weekly Pay
#
# Using **q2.py**, input the hourly pay rate and hours worked.\
# Calculate the weekly gross pay by multiplying hourly pay rate by hours worked.\
# Then take off 20% for tax (or calculate 80% of the gross value, which is the same thing) to get net pay.\
# **Example:** If hourly rate is £14.00 and hours worked is 20, then net pay is £224.00.
#
# ***
#
# ### 3. Movie Duration
#
# Write a function in **q3.py** that takes the length of a movie in minutes. Calculate the duration in hours and minutes.\
# Return a string in the format `hours:minutes`.
#
# ***
#
# ### 4. Loan Interest
#
# Using **q4.py**, input the amount borrowed, the annual interest rate (as a percentage), and the number of years elapsed. Calculate simple interest using the formula:\
# `interest = (amount × rate × years) / 100`\
# Output the interest rounded to 2 decimal places.
#
# ***
#
# ### 5. Energy Bill
#
# In **q5.py**, input the cost per unit and units used for both cheap rate and peak rate. Calculate the cost for each rate using:\
# `cost = units × rate`\
# Add both costs to get the total bill. Round the result to 2 decimal places.\
# **Example:** `(0.15 × 245) + (0.49 × 180) = £124.95`
#
# ***

# %%
# b6_exercises.py
''' 1. Shopping Bill
Input the prices of three items. Calculate the total and output it.
'''
item1 = None
item2 = None
item3 = None
total = None
print(total)

''' 2. Weekly Pay
Input the hourly pay rate and hours worked. Calculate the weekly gross pay by multiplying hourly pay rate by hours worked.
Then take off 20% for tax (or calculate 80% of the gross value, which is the same thing) to get net pay.
Round this to 2 decimal places.
Example: If hourly rate is 14.00 and hours worked is 20, then net pay is (14 * 20) * 80/100 = £224.00
'''
hourlyRate = None
hoursWorked = None
netPay = None
print(netPay)

''' 3. Movie Duration
Write a function that takes as a parameter the length of a movie in minutes.
Calculate the duration in hours and minutes, returning a string containing hours:minutes.
'''
def movie(minutes):
    hours = None
    mins = None
    result = None
    return result
# main program
print(movie(123))

''' 4. Loan Interest
You have borrowed money from a bank. The bank has loaned you an amount, with a fixed rate of interest per year, given as a percentage.
Input the amount, percentage interest rate and years elapsed.
The program will calculate simple interest using formula: interest = (amount × rate × years) / 100.
Output the interest to 2 decimal places.
'''
amount = None
rate = None
years = None
interest = None
print(interest)

''' 5. Energy Bill
An energy bill consists of an amount for the energy used at cheap rate, plus an amount for the energy used at peak rate.
Input the cheap rate cost per unit and units used at cheap rate, then input peak rate cost per unit and units used at peak rate.
For each rate, the cost is calculated by: cost = units × rate
Example: (0.15 * 245) + (0.49 * 180) = £124.95
Calculate the cost and output the value. Round the cost to 2 decimal places.
'''
cheapRate = None
cheapUnits = None
peakRate = None
peakUnits = None
totalCost = None
print(totalCost)

''' 6. Change Calculator
Write a program to output the quantity and value of each coin you need to use to give someone the correct change.
Coins available are £1 (100p), 50p, 20p, 10p, 5p, 2p and 1p.
Example input: £3.48
Example output: 3 x £1, 2 x 20p, 1 x 5p, 1 x 2p, 1 x 1p
Hint: use floor division and possibly modulus
'''
amount = 3.71 # try different values here
# Logic to calculate coins goes here

# %%
# q1.py
''' 1. Shopping Bill
Input the prices of three items. 
Calculate the total and output it.
Replace None below with your code.
'''
item1 = None
item2 = None
item3 = None
total = None
print(total)

# %%
# q2.py
''' 2. Weekly Pay
Input the hourly pay rate and hours worked. 
Calculate the weekly gross pay 
by multiplying hourly pay rate by hours worked.
Then take off 20% for tax (or calculate 80% of the gross value, 
which is the same thing) to get net pay.
Example: If hourly rate is 14.00 and hours worked is 20, 
then net pay is (14 * 20) * 80/100 = £224.00
Replace None in the code below with your code.
'''
hourlyRate = None
hoursWorked = None
netPay = None
print(netPay)

# %%
# q3.py
''' 3. Movie Duration
Write a function that takes as a parameter the length of a movie in minutes.
Calculate the duration in hours and minutes, returning a string containing hours:minutes.
'''
def movie(minutes):
    hours = None
    mins = None
    result = None
    return result
# main program
print(movie(123))

# %%
# q4.py
''' 4. Loan Interest
You have borrowed money from a bank. The bank has loaned you an amount, with a fixed rate of interest per year, given as a percentage.
Input the amount, percentage interest rate and years elapsed.
The program will calculate simple interest using formula: interest = (amount × rate × years) / 100.
Output the interest to 2 decimal places.
'''
amount = None
rate = None
years = None
interest = None
print(interest)

# %%
# q5.py
''' 5. Energy Bill
An energy bill consists of an amount for the energy used at cheap rate, plus an amount for the energy used at peak rate.
Input the cheap rate cost per unit and units used at cheap rate, then input peak rate cost per unit and units used at peak rate.
For each rate, the cost is calculated by: cost = units × rate
Example: (0.15 * 245) + (0.49 * 180) = £124.95
Calculate the cost and output the value. Round the cost to 2 decimal places.
'''
cheapRate = None
cheapUnits = None
peakRate = None
peakUnits = None
totalCost = None
print(totalCost)

# %% [markdown]
# *`q6.py` — write your code below*

# %%
# q6.py
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Capstone project - change calculator
#
# ### Capstone Project - Change Calculator
#
# # 💰⛃⛂⛁⛀💸
#
# You are programming the coin dispenser in a vending machine. Write a function to calculate the quantity and value of each coin needed to give correct change.
#
# Available coins: £1 (100p), 50p, 20p, 10p, 5p, 2p, 1p.
#
# **Example input:** £3.48
#
# **Example output:** `3 × £1, 2 × 20p, 1 × 5p, 1 × 2p, 1 × 1p`
#
# *Hint:* Convert input to pence, then use // (DIV) to decide how many times 100 goes into the amount - this is the £1 coins needed - and then use % (MOD) to calculate the remainder. Repeat this for every coin value!

# %%
# vending.py
def calcChange(amount):
    # write your code here

# %% [markdown]
# ---
